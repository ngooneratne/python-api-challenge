# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import scipy.stats as st
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 603

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | basotu
# Processing Record 2 of Set 1 | himatnagar
# Processing Record 3 of Set 1 | blackmans bay
# Processing Record 4 of Set 1 | grytviken
# Processing Record 5 of Set 1 | port-aux-francais
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | amga
# Processing Record 8 of Set 1 | lompoc
# Processing Record 9 of Set 1 | kavaratti
# Processing Record 10 of Set 1 | edinburgh of the seven seas
# Processing Record 11 of Set 1 | ahau
# City not found. Skipping...
# Processing Record 12 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 13 of Set 1 | columbia city
# Processing Record 14 of Set 1 | leava
# Processing Record 15 of Set 1 | uttar char fasson
# Processing Record 16 of Set 1 | nova sintra
# Processing Record 17 of Set 1 | kapa'a
# Processing Record 18 of Set 1 | ilulissat
# Processing Record 19 of Set 1 | luderitz
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | kodiak
# Processing Record 22 of Set 1 | port elizabeth
# Processing Record 23 of Set 1 | wailua homesteads
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | badger
# Processing Record 28 of Set 1 | lebu
# Processing Record 29 of Set 1 | fort st. john
# Processing Record 30 of Set 1 | fort mcmurray
# Processing Record 31 of Set 1 | bodo
# Processing Record 32 of Set 1 | mogadishu
# Processing Record 33 of Set 1 | kudat
# Processing Record 34 of Set 1 | margaret river
# Processing Record 35 of Set 1 | susuman
# Processing Record 36 of Set 1 | suva
# Processing Record 37 of Set 1 | papatowai
# Processing Record 38 of Set 1 | sharm el-sheikh
# Processing Record 39 of Set 1 | puerto natales
# Processing Record 40 of Set 1 | laguna paiva
# Processing Record 41 of Set 1 | college
# Processing Record 42 of Set 1 | adamstown
# Processing Record 43 of Set 1 | kapuskasing
# Processing Record 44 of Set 1 | yuzhno-kurilsk
# Processing Record 45 of Set 1 | isafjordur
# Processing Record 46 of Set 1 | bilibino
# Processing Record 47 of Set 1 | kingston
# Processing Record 48 of Set 1 | port mathurin
# Processing Record 49 of Set 1 | waitangi
# Processing Record 50 of Set 1 | mount isa
# Processing Record 0 of Set 2 | nuuk
# Processing Record 1 of Set 2 | huayucachi
# Processing Record 2 of Set 2 | invercargill
# Processing Record 3 of Set 2 | lorengau
# Processing Record 4 of Set 2 | wewak
# Processing Record 5 of Set 2 | tongchuan
# Processing Record 6 of Set 2 | mil'kovo
# Processing Record 7 of Set 2 | namibe
# Processing Record 8 of Set 2 | parnarama
# Processing Record 9 of Set 2 | west island
# Processing Record 10 of Set 2 | puerto colombia
# Processing Record 11 of Set 2 | longyearbyen
# Processing Record 12 of Set 2 | albany
# Processing Record 13 of Set 2 | borogontsy
# Processing Record 14 of Set 2 | sokoni
# Processing Record 15 of Set 2 | amboanjo
# Processing Record 16 of Set 2 | at taj
# Processing Record 17 of Set 2 | whitehorse
# Processing Record 18 of Set 2 | avarua
# Processing Record 19 of Set 2 | poggiardo
# Processing Record 20 of Set 2 | mossel bay
# Processing Record 21 of Set 2 | albertina
# Processing Record 22 of Set 2 | marquette
# Processing Record 23 of Set 2 | santa maria huatulco
# Processing Record 24 of Set 2 | constantia
# Processing Record 25 of Set 2 | umatac village
# City not found. Skipping...
# Processing Record 26 of Set 2 | gadzhiyevo
# Processing Record 27 of Set 2 | pandan
# Processing Record 28 of Set 2 | georgetown
# Processing Record 29 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 30 of Set 2 | hermanus
# Processing Record 31 of Set 2 | basco
# Processing Record 32 of Set 2 | tirebolu
# Processing Record 33 of Set 2 | cuajinicuilapa
# Processing Record 34 of Set 2 | carnarvon
# Processing Record 35 of Set 2 | keflavik
# Processing Record 36 of Set 2 | klyuchi
# Processing Record 37 of Set 2 | nykobing sjaelland
# Processing Record 38 of Set 2 | khandyga
# Processing Record 39 of Set 2 | salalah
# Processing Record 40 of Set 2 | kudahuvadhoo
# Processing Record 41 of Set 2 | kulia village
# City not found. Skipping...
# Processing Record 42 of Set 2 | mili
# Processing Record 43 of Set 2 | al kharijah
# Processing Record 44 of Set 2 | san kamphaeng
# Processing Record 45 of Set 2 | slave lake
# Processing Record 46 of Set 2 | bonthe
# Processing Record 47 of Set 2 | iqaluit
# Processing Record 48 of Set 2 | vadso
# Processing Record 49 of Set 2 | odlabari
# Processing Record 0 of Set 3 | cabo san lucas
# Processing Record 1 of Set 3 | olonkinbyen
# Processing Record 2 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 3 of Set 3 | debre tabor
# Processing Record 4 of Set 3 | stanley
# Processing Record 5 of Set 3 | balsas
# Processing Record 6 of Set 3 | saratamata
# City not found. Skipping...
# Processing Record 7 of Set 3 | kotido
# Processing Record 8 of Set 3 | remire-montjoly
# Processing Record 9 of Set 3 | rio do sul
# Processing Record 10 of Set 3 | kavieng
# Processing Record 11 of Set 3 | khovd
# Processing Record 12 of Set 3 | coahuayana de hidalgo
# Processing Record 13 of Set 3 | kani keli
# Processing Record 14 of Set 3 | thames
# Processing Record 15 of Set 3 | fale old settlement
# Processing Record 16 of Set 3 | palikir - national government center
# Processing Record 17 of Set 3 | mabaruma
# Processing Record 18 of Set 3 | kirensk
# Processing Record 19 of Set 3 | mukalla
# Processing Record 20 of Set 3 | yung shue wan
# Processing Record 21 of Set 3 | nadym
# Processing Record 22 of Set 3 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 23 of Set 3 | jamestown
# Processing Record 24 of Set 3 | bel ombre
# Processing Record 25 of Set 3 | garhi khairo
# Processing Record 26 of Set 3 | mount gambier
# Processing Record 27 of Set 3 | faya-largeau
# Processing Record 28 of Set 3 | caconda
# Processing Record 29 of Set 3 | perryville
# Processing Record 30 of Set 3 | puerto ayora
# Processing Record 31 of Set 3 | minas de marcona
# Processing Record 32 of Set 3 | codrington
# Processing Record 33 of Set 3 | xilin hot
# Processing Record 34 of Set 3 | punta arenas
# Processing Record 35 of Set 3 | andergrove
# Processing Record 36 of Set 3 | mahina
# Processing Record 37 of Set 3 | chonchi
# Processing Record 38 of Set 3 | arys
# Processing Record 39 of Set 3 | novodvinsk
# Processing Record 40 of Set 3 | pemangkat
# Processing Record 41 of Set 3 | salinopolis
# Processing Record 42 of Set 3 | namtsy
# Processing Record 43 of Set 3 | kurchum
# Processing Record 44 of Set 3 | gbadolite
# Processing Record 45 of Set 3 | tura
# Processing Record 46 of Set 3 | mount carmel
# Processing Record 47 of Set 3 | hamilton
# Processing Record 48 of Set 3 | amvrosiyivka
# Processing Record 49 of Set 3 | talnakh
# Processing Record 0 of Set 4 | iraquara
# Processing Record 1 of Set 4 | afaahiti
# Processing Record 2 of Set 4 | nogliki
# Processing Record 3 of Set 4 | cole harbour
# Processing Record 4 of Set 4 | goz beida
# Processing Record 5 of Set 4 | ke-macina
# Processing Record 6 of Set 4 | thompson
# Processing Record 7 of Set 4 | binuangan
# Processing Record 8 of Set 4 | labrador city
# Processing Record 9 of Set 4 | vilyuysk
# Processing Record 10 of Set 4 | howrah
# Processing Record 11 of Set 4 | tangalle
# Processing Record 12 of Set 4 | egilsstadir
# Processing Record 13 of Set 4 | uturoa
# Processing Record 14 of Set 4 | atherton
# Processing Record 15 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 16 of Set 4 | chibougamau
# Processing Record 17 of Set 4 | acapulco de juarez
# Processing Record 18 of Set 4 | port alfred
# Processing Record 19 of Set 4 | saudarkrokur
# Processing Record 20 of Set 4 | iskateley
# Processing Record 21 of Set 4 | murun-kuren
# Processing Record 22 of Set 4 | sedalia
# Processing Record 23 of Set 4 | hithadhoo
# Processing Record 24 of Set 4 | mount pearl
# Processing Record 25 of Set 4 | kristiansund
# Processing Record 26 of Set 4 | udachny
# Processing Record 27 of Set 4 | eisen
# Processing Record 28 of Set 4 | kajiki
# Processing Record 29 of Set 4 | crane
# Processing Record 30 of Set 4 | utrik
# Processing Record 31 of Set 4 | saint-pierre
# Processing Record 32 of Set 4 | atafu village
# Processing Record 33 of Set 4 | vilyuchinsk
# Processing Record 34 of Set 4 | tsiombe
# Processing Record 35 of Set 4 | debre sina
# Processing Record 36 of Set 4 | naryn
# Processing Record 37 of Set 4 | port douglas
# Processing Record 38 of Set 4 | luoyang
# Processing Record 39 of Set 4 | sur
# Processing Record 40 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 41 of Set 4 | bandar abbas
# Processing Record 42 of Set 4 | nova vicosa
# Processing Record 43 of Set 4 | calvinia
# Processing Record 44 of Set 4 | donvale
# Processing Record 45 of Set 4 | ad dilam
# Processing Record 46 of Set 4 | selfoss
# Processing Record 47 of Set 4 | kayangel
# Processing Record 48 of Set 4 | kaihua
# Processing Record 49 of Set 4 | polyarnyy
# Processing Record 0 of Set 5 | inhambane
# Processing Record 1 of Set 5 | nemuro
# Processing Record 2 of Set 5 | sitka
# Processing Record 3 of Set 5 | turan
# Processing Record 4 of Set 5 | papao
# Processing Record 5 of Set 5 | robel
# Processing Record 6 of Set 5 | ray
# Processing Record 7 of Set 5 | pointe-noire
# Processing Record 8 of Set 5 | tallulah
# Processing Record 9 of Set 5 | taman'
# Processing Record 10 of Set 5 | tanda
# Processing Record 11 of Set 5 | cabedelo
# Processing Record 12 of Set 5 | ashburton
# Processing Record 13 of Set 5 | labasa
# Processing Record 14 of Set 5 | happy valley-goose bay
# Processing Record 15 of Set 5 | queenstown
# Processing Record 16 of Set 5 | aasiaat
# Processing Record 17 of Set 5 | alofi
# Processing Record 18 of Set 5 | mukah
# City not found. Skipping...
# Processing Record 19 of Set 5 | rouissat
# Processing Record 20 of Set 5 | nar'yan-mar
# Processing Record 21 of Set 5 | hawaiian paradise park
# Processing Record 22 of Set 5 | arraial do cabo
# Processing Record 23 of Set 5 | los alamos
# Processing Record 24 of Set 5 | kimbe
# Processing Record 25 of Set 5 | pimentel
# Processing Record 26 of Set 5 | aleksandrovsk
# Processing Record 27 of Set 5 | cooper's town
# Processing Record 28 of Set 5 | luanda
# Processing Record 29 of Set 5 | alice springs
# Processing Record 30 of Set 5 | yeppoon
# Processing Record 31 of Set 5 | ancud
# Processing Record 32 of Set 5 | columbia falls
# Processing Record 33 of Set 5 | pacific grove
# Processing Record 34 of Set 5 | tual
# Processing Record 35 of Set 5 | praia da vitoria
# Processing Record 36 of Set 5 | puerto real
# Processing Record 37 of Set 5 | laguna
# Processing Record 38 of Set 5 | n'dalatando
# Processing Record 39 of Set 5 | ain sefra
# Processing Record 40 of Set 5 | geraldton
# Processing Record 41 of Set 5 | douz
# Processing Record 42 of Set 5 | san isidro
# Processing Record 43 of Set 5 | dhidhdhoo
# Processing Record 44 of Set 5 | mananjary
# Processing Record 45 of Set 5 | minehead
# Processing Record 46 of Set 5 | broken hill
# Processing Record 47 of Set 5 | coquimbo
# Processing Record 48 of Set 5 | mermoz boabab
# Processing Record 49 of Set 5 | san pedro
# Processing Record 0 of Set 6 | hami
# Processing Record 1 of Set 6 | big bend
# Processing Record 2 of Set 6 | mitsamiouli
# Processing Record 3 of Set 6 | arkhangel'sk
# Processing Record 4 of Set 6 | jiayuguan
# Processing Record 5 of Set 6 | ispica
# Processing Record 6 of Set 6 | colonia
# Processing Record 7 of Set 6 | vila velha
# Processing Record 8 of Set 6 | port said
# Processing Record 9 of Set 6 | lamu
# Processing Record 10 of Set 6 | lahaina
# Processing Record 11 of Set 6 | mhamid
# Processing Record 12 of Set 6 | am djarass
# City not found. Skipping...
# Processing Record 13 of Set 6 | kandiari
# Processing Record 14 of Set 6 | mar del plata
# Processing Record 15 of Set 6 | yeosu
# Processing Record 16 of Set 6 | mirante do paranapanema
# Processing Record 17 of Set 6 | mawu
# Processing Record 18 of Set 6 | whitecourt
# Processing Record 19 of Set 6 | okondja
# Processing Record 20 of Set 6 | sheridan
# Processing Record 21 of Set 6 | merritt
# Processing Record 22 of Set 6 | villa nueva
# Processing Record 23 of Set 6 | boguchar
# Processing Record 24 of Set 6 | pandaria
# Processing Record 25 of Set 6 | bontang
# Processing Record 26 of Set 6 | brigantine
# Processing Record 27 of Set 6 | upper grand lagoon
# Processing Record 28 of Set 6 | ferkessedougou
# Processing Record 29 of Set 6 | korsakov
# Processing Record 30 of Set 6 | trincomalee
# Processing Record 31 of Set 6 | vernon
# Processing Record 32 of Set 6 | yangor
# City not found. Skipping...
# Processing Record 33 of Set 6 | jalai nur
# Processing Record 34 of Set 6 | swan hill
# Processing Record 35 of Set 6 | viborg
# Processing Record 36 of Set 6 | farasan
# Processing Record 37 of Set 6 | shache
# Processing Record 38 of Set 6 | ondjiva
# Processing Record 39 of Set 6 | troitskaya
# Processing Record 40 of Set 6 | mantua
# Processing Record 41 of Set 6 | cidreira
# Processing Record 42 of Set 6 | puerto san jose
# Processing Record 43 of Set 6 | taltal
# Processing Record 44 of Set 6 | galliano
# Processing Record 45 of Set 6 | puerto baquerizo moreno
# Processing Record 46 of Set 6 | portland
# Processing Record 47 of Set 6 | gorontalo
# Processing Record 48 of Set 6 | bredasdorp
# Processing Record 49 of Set 6 | ola
# Processing Record 0 of Set 7 | ust-nera
# Processing Record 1 of Set 7 | sumbe
# Processing Record 2 of Set 7 | margate
# Processing Record 3 of Set 7 | vorkuta
# Processing Record 4 of Set 7 | priargunsk
# Processing Record 5 of Set 7 | sos'va
# Processing Record 6 of Set 7 | asilah
# Processing Record 7 of Set 7 | wellington
# Processing Record 8 of Set 7 | laihia
# Processing Record 9 of Set 7 | gravenwiesbach
# Processing Record 10 of Set 7 | parauapebas
# Processing Record 11 of Set 7 | maughold
# Processing Record 12 of Set 7 | bereznik
# Processing Record 13 of Set 7 | konosha
# Processing Record 14 of Set 7 | zhangatas
# Processing Record 15 of Set 7 | el calafate
# Processing Record 16 of Set 7 | kaohsiung
# Processing Record 17 of Set 7 | hammerfest
# Processing Record 18 of Set 7 | skowhegan
# Processing Record 19 of Set 7 | sao vicente
# Processing Record 20 of Set 7 | jodhpur
# Processing Record 21 of Set 7 | marsh harbour
# Processing Record 22 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 23 of Set 7 | lihue
# Processing Record 24 of Set 7 | bayanhongor
# Processing Record 25 of Set 7 | paracuru
# Processing Record 26 of Set 7 | rongelap
# Processing Record 27 of Set 7 | illizi
# Processing Record 28 of Set 7 | canete
# Processing Record 29 of Set 7 | kodinsk
# Processing Record 30 of Set 7 | mejit
# Processing Record 31 of Set 7 | zouerate
# Processing Record 32 of Set 7 | altai
# Processing Record 33 of Set 7 | fortuna
# Processing Record 34 of Set 7 | east falmouth
# Processing Record 35 of Set 7 | pangoa
# Processing Record 36 of Set 7 | ludvika
# Processing Record 37 of Set 7 | gueltat zemmour
# City not found. Skipping...
# Processing Record 38 of Set 7 | willowmore
# Processing Record 39 of Set 7 | las navas del marques
# Processing Record 40 of Set 7 | dryden
# Processing Record 41 of Set 7 | angaur state
# Processing Record 42 of Set 7 | podporozh'ye
# Processing Record 43 of Set 7 | puente alto
# Processing Record 44 of Set 7 | arroio grande
# Processing Record 45 of Set 7 | linxia chengguanzhen
# Processing Record 46 of Set 7 | yagry
# City not found. Skipping...
# Processing Record 47 of Set 7 | murghob
# Processing Record 48 of Set 7 | greater sudbury
# Processing Record 49 of Set 7 | byron bay
# Processing Record 0 of Set 8 | erenhot
# Processing Record 1 of Set 8 | ongjin
# Processing Record 2 of Set 8 | kenda
# Processing Record 3 of Set 8 | yeniseysk
# Processing Record 4 of Set 8 | port augusta
# Processing Record 5 of Set 8 | kidal
# Processing Record 6 of Set 8 | taro
# Processing Record 7 of Set 8 | dudinka
# Processing Record 8 of Set 8 | gerash
# Processing Record 9 of Set 8 | mahdia
# Processing Record 10 of Set 8 | galesong
# Processing Record 11 of Set 8 | forster
# Processing Record 12 of Set 8 | flying fish cove
# Processing Record 13 of Set 8 | cabrobo
# Processing Record 14 of Set 8 | sinabang
# Processing Record 15 of Set 8 | lucapa
# Processing Record 16 of Set 8 | darwin
# Processing Record 17 of Set 8 | talas
# Processing Record 18 of Set 8 | malvan
# Processing Record 19 of Set 8 | bat khela
# Processing Record 20 of Set 8 | nizhnesortymskiy
# Processing Record 21 of Set 8 | aykhal
# Processing Record 22 of Set 8 | puerto deseado
# Processing Record 23 of Set 8 | osorno
# Processing Record 24 of Set 8 | arthur's town
# City not found. Skipping...
# Processing Record 25 of Set 8 | hadithah
# Processing Record 26 of Set 8 | gisborne
# Processing Record 27 of Set 8 | amlapura
# Processing Record 28 of Set 8 | murrells inlet
# Processing Record 29 of Set 8 | hamah
# Processing Record 30 of Set 8 | st. john's
# Processing Record 31 of Set 8 | rundu
# Processing Record 32 of Set 8 | smithers
# Processing Record 33 of Set 8 | thakhek
# Processing Record 34 of Set 8 | tralee
# Processing Record 35 of Set 8 | beyla
# Processing Record 36 of Set 8 | yur'yev-pol'skiy
# Processing Record 37 of Set 8 | wynyard
# Processing Record 38 of Set 8 | federal
# Processing Record 39 of Set 8 | acarau
# Processing Record 40 of Set 8 | tazovsky
# Processing Record 41 of Set 8 | odawara
# Processing Record 42 of Set 8 | mstera
# Processing Record 43 of Set 8 | ar rutbah
# Processing Record 44 of Set 8 | lagos
# Processing Record 45 of Set 8 | point pedro
# Processing Record 46 of Set 8 | sao jose da coroa grande
# Processing Record 47 of Set 8 | namalenga
# Processing Record 48 of Set 8 | mahibadhoo
# Processing Record 49 of Set 8 | zhizdra
# Processing Record 0 of Set 9 | fort bragg
# Processing Record 1 of Set 9 | saint-philippe
# Processing Record 2 of Set 9 | weno
# Processing Record 3 of Set 9 | sabang
# Processing Record 4 of Set 9 | saipan
# Processing Record 5 of Set 9 | imbituba
# Processing Record 6 of Set 9 | alaghsas
# Processing Record 7 of Set 9 | vorgashor
# Processing Record 8 of Set 9 | sorong
# Processing Record 9 of Set 9 | greymouth
# Processing Record 10 of Set 9 | kone
# Processing Record 11 of Set 9 | ovalle
# Processing Record 12 of Set 9 | huarmey
# Processing Record 13 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 14 of Set 9 | sungai penuh
# Processing Record 15 of Set 9 | chui
# Processing Record 16 of Set 9 | polonne
# Processing Record 17 of Set 9 | nguruka
# Processing Record 18 of Set 9 | male
# Processing Record 19 of Set 9 | karkira
# Processing Record 20 of Set 9 | ulsteinvik
# Processing Record 21 of Set 9 | brookings
# Processing Record 22 of Set 9 | qaqortoq
# Processing Record 23 of Set 9 | nannilam
# Processing Record 24 of Set 9 | east london
# Processing Record 25 of Set 9 | saldanha
# Processing Record 26 of Set 9 | teluknaga
# Processing Record 27 of Set 9 | salym
# Processing Record 28 of Set 9 | myeik
# Processing Record 29 of Set 9 | ribeira brava
# Processing Record 30 of Set 9 | taroa
# Processing Record 31 of Set 9 | walvis bay
# Processing Record 32 of Set 9 | martuk
# Processing Record 33 of Set 9 | daru
# Processing Record 34 of Set 9 | metlili chaamba
# Processing Record 35 of Set 9 | kailua-kona
# Processing Record 36 of Set 9 | ocean shores
# Processing Record 37 of Set 9 | guarapari
# Processing Record 38 of Set 9 | hasaki
# Processing Record 39 of Set 9 | ponta delgada
# Processing Record 40 of Set 9 | nadi
# Processing Record 41 of Set 9 | ghazni
# Processing Record 42 of Set 9 | rio turbio
# City not found. Skipping...
# Processing Record 43 of Set 9 | banda aceh
# Processing Record 44 of Set 9 | san juan nepomuceno
# Processing Record 45 of Set 9 | kiunga
# Processing Record 46 of Set 9 | aksu
# Processing Record 47 of Set 9 | waingapu
# Processing Record 48 of Set 9 | mana
# Processing Record 49 of Set 9 | sandnessjoen
# Processing Record 0 of Set 10 | xinzhou
# Processing Record 1 of Set 10 | sydney
# Processing Record 2 of Set 10 | hwange
# Processing Record 3 of Set 10 | pisco
# Processing Record 4 of Set 10 | vingt cinq
# City not found. Skipping...
# Processing Record 5 of Set 10 | urzhar
# Processing Record 6 of Set 10 | blackwater
# Processing Record 7 of Set 10 | taibet
# City not found. Skipping...
# Processing Record 8 of Set 10 | wilton
# Processing Record 9 of Set 10 | xining
# Processing Record 10 of Set 10 | sucua
# Processing Record 11 of Set 10 | oyama
# Processing Record 12 of Set 10 | coos bay
# Processing Record 13 of Set 10 | kaga bandoro
# Processing Record 14 of Set 10 | xunchang
# Processing Record 15 of Set 10 | dourbali
# Processing Record 16 of Set 10 | antonio enes
# Processing Record 17 of Set 10 | tofol
# Processing Record 18 of Set 10 | arak
# Processing Record 19 of Set 10 | yanchep
# Processing Record 20 of Set 10 | maumere
# Processing Record 21 of Set 10 | ghanzi
# Processing Record 22 of Set 10 | tabou
# Processing Record 23 of Set 10 | igrim
# Processing Record 24 of Set 10 | guangyuan
# Processing Record 25 of Set 10 | olinda
# Processing Record 26 of Set 10 | kawalu
# Processing Record 27 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 10 | adrogue
# City not found. Skipping...
# Processing Record 29 of Set 10 | takamaka
# City not found. Skipping...
# Processing Record 30 of Set 10 | nampa
# Processing Record 31 of Set 10 | ndele
# Processing Record 32 of Set 10 | bogande
# Processing Record 33 of Set 10 | anadyr
# Processing Record 34 of Set 10 | poli
# Processing Record 35 of Set 10 | lushun
# Processing Record 36 of Set 10 | ataq
# Processing Record 37 of Set 10 | sayula de aleman
# Processing Record 38 of Set 10 | santa cruz
# Processing Record 39 of Set 10 | larache
# Processing Record 40 of Set 10 | korla
# Processing Record 41 of Set 10 | mumford
# Processing Record 42 of Set 10 | konigsbach-stein
# Processing Record 43 of Set 10 | tadine
# Processing Record 44 of Set 10 | san fernando de monte cristi
# Processing Record 45 of Set 10 | puerto santa
# Processing Record 46 of Set 10 | laghouat
# Processing Record 47 of Set 10 | el fasher
# Processing Record 48 of Set 10 | san carlos
# Processing Record 49 of Set 10 | bengkulu
# Processing Record 0 of Set 11 | quellon
# Processing Record 1 of Set 11 | lobito
# Processing Record 2 of Set 11 | sovetskaya gavan'
# Processing Record 3 of Set 11 | sakakah
# Processing Record 4 of Set 11 | cairns city
# City not found. Skipping...
# Processing Record 5 of Set 11 | gangolli
# Processing Record 6 of Set 11 | san antonio de pale
# Processing Record 7 of Set 11 | hilo
# Processing Record 8 of Set 11 | nagqu
# Processing Record 9 of Set 11 | al fuwayliq
# Processing Record 10 of Set 11 | wamba
# Processing Record 11 of Set 11 | marudi
# City not found. Skipping...
# Processing Record 12 of Set 11 | menominee
# Processing Record 13 of Set 11 | kulhudhuffushi
# Processing Record 14 of Set 11 | porto novo
# Processing Record 15 of Set 11 | k'olito
# Processing Record 16 of Set 11 | gaspe
# Processing Record 17 of Set 11 | flin flon
# Processing Record 18 of Set 11 | tolanaro
# Processing Record 19 of Set 11 | kagoro
# Processing Record 20 of Set 11 | fremont
# Processing Record 21 of Set 11 | tshela
# Processing Record 22 of Set 11 | marhanets'
# City not found. Skipping...
# Processing Record 23 of Set 11 | ranau
# Processing Record 24 of Set 11 | masterton
# Processing Record 25 of Set 11 | whakatane
# Processing Record 26 of Set 11 | rawson
# Processing Record 27 of Set 11 | cinarcik
# Processing Record 28 of Set 11 | cushing
# Processing Record 29 of Set 11 | saquarema
# Processing Record 30 of Set 11 | luganville
# Processing Record 31 of Set 11 | kineshma
# Processing Record 32 of Set 11 | devils lake
# Processing Record 33 of Set 11 | haiku-pauwela
# Processing Record 34 of Set 11 | ad dabbah
# Processing Record 35 of Set 11 | linxi
# Processing Record 36 of Set 11 | la ronge
# Processing Record 37 of Set 11 | araguaina
# Processing Record 38 of Set 11 | santiago de cuba
# Processing Record 39 of Set 11 | bodaybo
# Processing Record 40 of Set 11 | tamiahua
# Processing Record 41 of Set 11 | liepaja
# Processing Record 42 of Set 11 | paramonga
# Processing Record 43 of Set 11 | sierra grande
# Processing Record 44 of Set 11 | dunedin
# Processing Record 45 of Set 11 | makinsk
# Processing Record 46 of Set 11 | viedma
# Processing Record 47 of Set 11 | horodnytsya
# Processing Record 48 of Set 11 | saint-louis
# Processing Record 49 of Set 11 | sao joao da barra
# Processing Record 0 of Set 12 | nantucket
# Processing Record 1 of Set 12 | san patricio
# Processing Record 2 of Set 12 | soe
# Processing Record 3 of Set 12 | blenheim
# Processing Record 4 of Set 12 | callao
# Processing Record 5 of Set 12 | malanje
# Processing Record 6 of Set 12 | hun
# Processing Record 7 of Set 12 | la passe
# Processing Record 8 of Set 12 | benguela
# Processing Record 9 of Set 12 | gereida
# Processing Record 10 of Set 12 | las heras
# Processing Record 11 of Set 12 | morehead
# Processing Record 12 of Set 12 | luwuk
# Processing Record 13 of Set 12 | vila franca do campo
# Processing Record 14 of Set 12 | touros
# Processing Record 15 of Set 12 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 16 of Set 12 | hovd
# Processing Record 17 of Set 12 | am timan
# Processing Record 18 of Set 12 | cockburn town
# Processing Record 19 of Set 12 | castillos
# Processing Record 20 of Set 12 | camarinas
# Processing Record 21 of Set 12 | sanctuary point
# Processing Record 22 of Set 12 | chos malal
# Processing Record 23 of Set 12 | les avirons
# Processing Record 24 of Set 12 | bloomfield
# Processing Record 25 of Set 12 | riedering
# Processing Record 26 of Set 12 | barah
# Processing Record 27 of Set 12 | al jawf
# Processing Record 28 of Set 12 | torit
# Processing Record 29 of Set 12 | ballina
# Processing Record 30 of Set 12 | santyoku
# Processing Record 31 of Set 12 | campoverde
# Processing Record 32 of Set 12 | 'ain merane
# Processing Record 33 of Set 12 | klaksvik
# Processing Record 34 of Set 12 | guiuan
# Processing Record 35 of Set 12 | usinsk
# Processing Record 36 of Set 12 | zaozersk
# Processing Record 37 of Set 12 | paita
# Processing Record 38 of Set 12 | motygino
# Processing Record 39 of Set 12 | aur
# Processing Record 40 of Set 12 | gamba
# Processing Record 41 of Set 12 | holualoa
# Processing Record 42 of Set 12 | vallenar
# Processing Record 43 of Set 12 | ormara
# Processing Record 44 of Set 12 | shagonar
# Processing Record 45 of Set 12 | kununurra
# Processing Record 46 of Set 12 | puerto rico
# Processing Record 47 of Set 12 | lazaro cardenas
# Processing Record 48 of Set 12 | madalena
# Processing Record 49 of Set 12 | alta
# Processing Record 0 of Set 13 | san julian
# Processing Record 1 of Set 13 | znamenskoye
# Processing Record 2 of Set 13 | bangassou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather
# Out:
# {'coord': {'lon': 22.8184, 'lat': 4.7413},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 307.03,
#   'feels_like': 307.22,
#   'temp_min': 307.03,
#   'temp_max': 307.03,
#   'pressure': 1007,
#   'humidity': 35,
#   'sea_level': 1007,
#   'grnd_level': 953},
#  'visibility': 10000,
#  'wind': {'speed': 3.32, 'deg': 145, 'gust': 4.08},
#  'clouds': {'all': 45},
#  'dt': 1683811309,
#  'sys': {'country': 'CF', 'sunrise': 1683778533, 'sunset': 1683822885},
#  'timezone': 3600,
#  'id': 240498,
#  'name': 'Bangassou',
#  'cod': 200}

# %%
city_data
# Out:
# [{'City': 'basotu',
#   'Lat': -4.3667,
#   'Lng': 35.0833,
#   'Max Temp': 294.15,
#   'Humidity': 60,
#   'Cloudiness': 55,
#   'Wind Speed': 2.96,
#   'Country': 'TZ',
#   'Date': 1683818132},
#  {'City': 'himatnagar',
#   'Lat': 23.6,
#   'Lng': 72.95,
#   'Max Temp': 308.78,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Country': 'IN',
#   'Date': 1683818132},
#  {'City': 'blackmans bay',
#   'Lat': -43.0167,
#   'Lng': 147.3167,
#   'Max Temp': 282.22,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 2.73,
#   'Country': 'AU',
#   'Date': 1683818132},
#  {'City': 'grytviken',
#   'Lat': -54.2811,
#   'Lng': -36.5092,
#   'Max Temp': 271.36,
#   'Humidity': 76,
#   'Cloudiness': 41,
#   'Wind Speed': 4.6,
#   'Country': 'GS',
#   'Date': 1683818132},
#  {'City': 'port-aux-francais',
#   'Lat': -49.35,
#   'Lng': 70.2167,
#   'Max Temp': 280.56,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 17.36,
#   'Country': 'TF',
#   'Date': 1683818132},
#  {'City': 'yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 283.46,
#   'Humidity': 53,
#   'Cloudiness': 2,
#   'Wind Speed': 4.47,
#   'Country': 'CA',
#   'Date': 1683818132},
#  {'City': 'amga',
#   'Lat': 60.8953,
#   'Lng': 131.9608,
#   'Max Temp': 273.77,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.33,
#   'Country': 'RU',
#   'Date': 1683818133},
#  {'City': 'lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 286.4,
#   'Humidity': 83,
#   'Cloudiness': 70,
#   'Wind Speed': 1.34,
#   'Country': 'US',
#   'Date': 1683818133},
#  {'City': 'kavaratti',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 302.83,
#   'Humidity': 71,
#   'Cloudiness': 55,
#   'Wind Speed': 2.5,
#   'Country': 'IN',
#   'Date': 1683818133},
#  {'City': 'edinburgh of the seven seas',
#   'Lat': -37.0676,
#   'Lng': -12.3116,
#   'Max Temp': 289.39,
#   'Humidity': 75,
#   'Cloudiness': 94,
#   'Wind Speed': 10.84,
#   'Country': 'SH',
#   'Date': 1683818133},
#  {'City': 'columbia city',
#   'Lat': 41.1573,
#   'Lng': -85.4883,
#   'Max Temp': 296.1,
#   'Humidity': 47,
#   'Cloudiness': 97,
#   'Wind Speed': 3.13,
#   'Country': 'US',
#   'Date': 1683818020},
#  {'City': 'leava',
#   'Lat': -14.3,
#   'Lng': -178.1667,
#   'Max Temp': 301.63,
#   'Humidity': 74,
#   'Cloudiness': 9,
#   'Wind Speed': 8.07,
#   'Country': 'WF',
#   'Date': 1683818134},
#  {'City': 'uttar char fasson',
#   'Lat': 22.2332,
#   'Lng': 90.7132,
#   'Max Temp': 302.74,
#   'Humidity': 72,
#   'Cloudiness': 94,
#   'Wind Speed': 6.66,
#   'Country': 'BD',
#   'Date': 1683818134},
#  {'City': 'nova sintra',
#   'Lat': 14.8667,
#   'Lng': -24.7167,
#   'Max Temp': 293.18,
#   'Humidity': 82,
#   'Cloudiness': 4,
#   'Wind Speed': 8.43,
#   'Country': 'CV',
#   'Date': 1683818134},
#  {'City': "kapa'a",
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 296.33,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Country': 'US',
#   'Date': 1683818134},
#  {'City': 'ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 271.16,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 7.2,
#   'Country': 'GL',
#   'Date': 1683818134},
#  {'City': 'luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 293.05,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 10.07,
#   'Country': 'NA',
#   'Date': 1683818135},
#  {'City': 'ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 279.96,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Country': 'AR',
#   'Date': 1683818135},
#  {'City': 'kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 277.88,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': 1683818135},
#  {'City': 'port elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 293.31,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 9.77,
#   'Country': 'ZA',
#   'Date': 1683818135},
#  {'City': 'wailua homesteads',
#   'Lat': 22.0669,
#   'Lng': -159.378,
#   'Max Temp': 295.59,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Country': 'US',
#   'Date': 1683818135},
#  {'City': 'ribeira grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 293.02,
#   'Humidity': 72,
#   'Cloudiness': 20,
#   'Wind Speed': 6.71,
#   'Country': 'PT',
#   'Date': 1683818135},
#  {'City': 'tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 261.84,
#   'Humidity': 79,
#   'Cloudiness': 84,
#   'Wind Speed': 12.02,
#   'Country': 'RU',
#   'Date': 1683818136},
#  {'City': 'bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 296.23,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'US',
#   'Date': 1683818136},
#  {'City': 'badger',
#   'Lat': 64.8,
#   'Lng': -147.5333,
#   'Max Temp': 281.38,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1683818136},
#  {'City': 'lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 288.31,
#   'Humidity': 78,
#   'Cloudiness': 56,
#   'Wind Speed': 2.84,
#   'Country': 'CL',
#   'Date': 1683818136},
#  {'City': 'fort st. john',
#   'Lat': 56.2499,
#   'Lng': -120.8529,
#   'Max Temp': 285.98,
#   'Humidity': 58,
#   'Cloudiness': 52,
#   'Wind Speed': 1.7,
#   'Country': 'CA',
#   'Date': 1683818137},
#  {'City': 'fort mcmurray',
#   'Lat': 56.7268,
#   'Lng': -111.381,
#   'Max Temp': 289.83,
#   'Humidity': 48,
#   'Cloudiness': 96,
#   'Wind Speed': 1.09,
#   'Country': 'CA',
#   'Date': 1683817935},
#  {'City': 'bodo',
#   'Lat': 67.28,
#   'Lng': 14.405,
#   'Max Temp': 280.9,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.14,
#   'Country': 'NO',
#   'Date': 1683818137},
#  {'City': 'mogadishu',
#   'Lat': 2.0371,
#   'Lng': 45.3438,
#   'Max Temp': 300.64,
#   'Humidity': 83,
#   'Cloudiness': 24,
#   'Wind Speed': 7.47,
#   'Country': 'SO',
#   'Date': 1683817941},
#  {'City': 'kudat',
#   'Lat': 6.8837,
#   'Lng': 116.8477,
#   'Max Temp': 300.25,
#   'Humidity': 83,
#   'Cloudiness': 78,
#   'Wind Speed': 3.11,
#   'Country': 'MY',
#   'Date': 1683818137},
#  {'City': 'margaret river',
#   'Lat': -33.95,
#   'Lng': 115.0667,
#   'Max Temp': 284.91,
#   'Humidity': 68,
#   'Cloudiness': 15,
#   'Wind Speed': 2.4,
#   'Country': 'AU',
#   'Date': 1683818137},
#  {'City': 'susuman',
#   'Lat': 62.7833,
#   'Lng': 148.1667,
#   'Max Temp': 272.28,
#   'Humidity': 89,
#   'Cloudiness': 93,
#   'Wind Speed': 1.56,
#   'Country': 'RU',
#   'Date': 1683818138},
#  {'City': 'suva',
#   'Lat': -18.1416,
#   'Lng': 178.4415,
#   'Max Temp': 295.86,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.06,
#   'Country': 'FJ',
#   'Date': 1683817664},
#  {'City': 'papatowai',
#   'Lat': -46.5619,
#   'Lng': 169.4708,
#   'Max Temp': 283.81,
#   'Humidity': 89,
#   'Cloudiness': 89,
#   'Wind Speed': 6.77,
#   'Country': 'NZ',
#   'Date': 1683818138},
#  {'City': 'sharm el-sheikh',
#   'Lat': 27.8518,
#   'Lng': 34.305,
#   'Max Temp': 300.48,
#   'Humidity': 47,
#   'Cloudiness': 2,
#   'Wind Speed': 3.15,
#   'Country': 'EG',
#   'Date': 1683818138},
#  {'City': 'puerto natales',
#   'Lat': -51.7236,
#   'Lng': -72.4875,
#   'Max Temp': 282.4,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 0.51,
#   'Country': 'CL',
#   'Date': 1683818138},
#  {'City': 'laguna paiva',
#   'Lat': -31.3039,
#   'Lng': -60.6589,
#   'Max Temp': 292.58,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 1.79,
#   'Country': 'AR',
#   'Date': 1683818138},
#  {'City': 'college',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': 281.43,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 0.45,
#   'Country': 'US',
#   'Date': 1683818043},
#  {'City': 'adamstown',
#   'Lat': -25.066,
#   'Lng': -130.1015,
#   'Max Temp': 294.68,
#   'Humidity': 55,
#   'Cloudiness': 91,
#   'Wind Speed': 9.2,
#   'Country': 'PN',
#   'Date': 1683818139},
#  {'City': 'kapuskasing',
#   'Lat': 49.4169,
#   'Lng': -82.4331,
#   'Max Temp': 292.53,
#   'Humidity': 46,
#   'Cloudiness': 100,
#   'Wind Speed': 3.4,
#   'Country': 'CA',
#   'Date': 1683817982},
#  {'City': 'yuzhno-kurilsk',
#   'Lat': 44.0306,
#   'Lng': 145.8556,
#   'Max Temp': 275.51,
#   'Humidity': 85,
#   'Cloudiness': 13,
#   'Wind Speed': 3.75,
#   'Country': 'RU',
#   'Date': 1683818139},
#  {'City': 'isafjordur',
#   'Lat': 66.0755,
#   'Lng': -23.124,
#   'Max Temp': 281.17,
#   'Humidity': 81,
#   'Cloudiness': 40,
#   'Wind Speed': 5.14,
#   'Country': 'IS',
#   'Date': 1683818139},
#  {'City': 'bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': 269.41,
#   'Humidity': 94,
#   'Cloudiness': 96,
#   'Wind Speed': 0.33,
#   'Country': 'RU',
#   'Date': 1683818139},
#  {'City': 'kingston',
#   'Lat': 17.997,
#   'Lng': -76.7936,
#   'Max Temp': 304.4,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 1.79,
#   'Country': 'JM',
#   'Date': 1683817943},
#  {'City': 'port mathurin',
#   'Lat': -19.6833,
#   'Lng': 63.4167,
#   'Max Temp': 298.92,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 9.24,
#   'Country': 'MU',
#   'Date': 1683818140},
#  {'City': 'waitangi',
#   'Lat': -43.9535,
#   'Lng': -176.5597,
#   'Max Temp': 284.11,
#   'Humidity': 57,
#   'Cloudiness': 89,
#   'Wind Speed': 10.39,
#   'Country': 'NZ',
#   'Date': 1683818140},
#  {'City': 'mount isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 289.02,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'AU',
#   'Date': 1683818140},
#  {'City': 'nuuk',
#   'Lat': 64.1835,
#   'Lng': -51.7216,
#   'Max Temp': 275.49,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 4.12,
#   'Country': 'GL',
#   'Date': 1683818140},
#  {'City': 'huayucachi',
#   'Lat': -12.1333,
#   'Lng': -75.2333,
#   'Max Temp': 287.04,
#   'Humidity': 53,
#   'Cloudiness': 62,
#   'Wind Speed': 0.89,
#   'Country': 'PE',
#   'Date': 1683818140},
#  {'City': 'invercargill',
#   'Lat': -46.4,
#   'Lng': 168.35,
#   'Max Temp': 281.49,
#   'Humidity': 95,
#   'Cloudiness': 84,
#   'Wind Speed': 1.34,
#   'Country': 'NZ',
#   'Date': 1683817860},
#  {'City': 'lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 300.63,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 1.91,
#   'Country': 'PG',
#   'Date': 1683818141},
#  {'City': 'wewak',
#   'Lat': -3.5534,
#   'Lng': 143.6268,
#   'Max Temp': 300.49,
#   'Humidity': 81,
#   'Cloudiness': 98,
#   'Wind Speed': 2.12,
#   'Country': 'PG',
#   'Date': 1683818141},
#  {'City': 'tongchuan',
#   'Lat': 35.0806,
#   'Lng': 109.0897,
#   'Max Temp': 288.46,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 2.08,
#   'Country': 'CN',
#   'Date': 1683818141},
#  {'City': "mil'kovo",
#   'Lat': 55.6078,
#   'Lng': 37.7956,
#   'Max Temp': 291.37,
#   'Humidity': 46,
#   'Cloudiness': 78,
#   'Wind Speed': 3.71,
#   'Country': 'RU',
#   'Date': 1683818141},
#  {'City': 'namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 298.76,
#   'Humidity': 68,
#   'Cloudiness': 12,
#   'Wind Speed': 2.81,
#   'Country': 'AO',
#   'Date': 1683818141},
#  {'City': 'parnarama',
#   'Lat': -5.6817,
#   'Lng': -43.0933,
#   'Max Temp': 307.38,
#   'Humidity': 45,
#   'Cloudiness': 70,
#   'Wind Speed': 0.91,
#   'Country': 'BR',
#   'Date': 1683818141},
#  {'City': 'west island',
#   'Lat': -12.1568,
#   'Lng': 96.8225,
#   'Max Temp': 302.14,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Country': 'CC',
#   'Date': 1683818142},
#  {'City': 'puerto colombia',
#   'Lat': 10.9878,
#   'Lng': -74.9547,
#   'Max Temp': 305.2,
#   'Humidity': 75,
#   'Cloudiness': 98,
#   'Wind Speed': 4.31,
#   'Country': 'CO',
#   'Date': 1683817931},
#  {'City': 'longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 273.06,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 9.26,
#   'Country': 'SJ',
#   'Date': 1683818142},
#  {'City': 'albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 295.31,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 0.89,
#   'Country': 'US',
#   'Date': 1683818142},
#  {'City': 'borogontsy',
#   'Lat': 62.6683,
#   'Lng': 131.1683,
#   'Max Temp': 270.72,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 3.12,
#   'Country': 'RU',
#   'Date': 1683818142},
#  {'City': 'sokoni',
#   'Lat': -6.4333,
#   'Lng': 39.55,
#   'Max Temp': 300.36,
#   'Humidity': 79,
#   'Cloudiness': 7,
#   'Wind Speed': 5.73,
#   'Country': 'TZ',
#   'Date': 1683818143},
#  {'City': 'amboanjo',
#   'Lat': -22.6667,
#   'Lng': 47.8167,
#   'Max Temp': 296.26,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 2.61,
#   'Country': 'MG',
#   'Date': 1683818143},
#  {'City': 'at taj',
#   'Lat': 24.2049,
#   'Lng': 23.2857,
#   'Max Temp': 303.33,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 6.46,
#   'Country': 'LY',
#   'Date': 1683818143},
#  {'City': 'whitehorse',
#   'Lat': 60.7161,
#   'Lng': -135.0538,
#   'Max Temp': 280.38,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 4.92,
#   'Country': 'CA',
#   'Date': 1683817976},
#  {'City': 'avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 298.18,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 4.12,
#   'Country': 'CK',
#   'Date': 1683817895},
#  {'City': 'poggiardo',
#   'Lat': 40.0542,
#   'Lng': 18.3791,
#   'Max Temp': 292.85,
#   'Humidity': 75,
#   'Cloudiness': 14,
#   'Wind Speed': 6.93,
#   'Country': 'IT',
#   'Date': 1683818143},
#  {'City': 'mossel bay',
#   'Lat': -34.1831,
#   'Lng': 22.146,
#   'Max Temp': 288.11,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 8.13,
#   'Country': 'ZA',
#   'Date': 1683818143},
#  {'City': 'albertina',
#   'Lat': -22.2008,
#   'Lng': -46.6158,
#   'Max Temp': 294.75,
#   'Humidity': 69,
#   'Cloudiness': 43,
#   'Wind Speed': 2.83,
#   'Country': 'BR',
#   'Date': 1683818144},
#  {'City': 'marquette',
#   'Lat': 46.5333,
#   'Lng': -87.6335,
#   'Max Temp': 296.36,
#   'Humidity': 47,
#   'Cloudiness': 5,
#   'Wind Speed': 3.58,
#   'Country': 'US',
#   'Date': 1683818144},
#  {'City': 'santa maria huatulco',
#   'Lat': 15.8436,
#   'Lng': -96.3267,
#   'Max Temp': 302.52,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'MX',
#   'Date': 1683818144},
#  {'City': 'constantia',
#   'Lat': 44.1833,
#   'Lng': 28.65,
#   'Max Temp': 287.53,
#   'Humidity': 63,
#   'Cloudiness': 56,
#   'Wind Speed': 5.15,
#   'Country': 'RO',
#   'Date': 1683818144},
#  {'City': 'gadzhiyevo',
#   'Lat': 69.2551,
#   'Lng': 33.3362,
#   'Max Temp': 276.65,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Country': 'RU',
#   'Date': 1683817847},
#  {'City': 'pandan',
#   'Lat': 14.0453,
#   'Lng': 124.1694,
#   'Max Temp': 300.01,
#   'Humidity': 81,
#   'Cloudiness': 28,
#   'Wind Speed': 2.99,
#   'Country': 'PH',
#   'Date': 1683818144},
#  {'City': 'georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 303.12,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'MY',
#   'Date': 1683817918},
#  {'City': 'petropavlovsk-kamchatsky',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 273.48,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'RU',
#   'Date': 1683818145},
#  {'City': 'hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 285.82,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 4.84,
#   'Country': 'ZA',
#   'Date': 1683818145},
#  {'City': 'basco',
#   'Lat': 20.4487,
#   'Lng': 121.9702,
#   'Max Temp': 298.67,
#   'Humidity': 71,
#   'Cloudiness': 13,
#   'Wind Speed': 7.36,
#   'Country': 'PH',
#   'Date': 1683818145},
#  {'City': 'tirebolu',
#   'Lat': 41.0069,
#   'Lng': 38.8139,
#   'Max Temp': 285.42,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.25,
#   'Country': 'TR',
#   'Date': 1683818145},
#  {'City': 'cuajinicuilapa',
#   'Lat': 16.4667,
#   'Lng': -98.4167,
#   'Max Temp': 303.67,
#   'Humidity': 56,
#   'Cloudiness': 12,
#   'Wind Speed': 2.49,
#   'Country': 'MX',
#   'Date': 1683818145},
#  {'City': 'carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 295.33,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 8.26,
#   'Country': 'AU',
#   'Date': 1683818146},
#  {'City': 'keflavik',
#   'Lat': 64.0049,
#   'Lng': -22.5624,
#   'Max Temp': 283.1,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 10.29,
#   'Country': 'IS',
#   'Date': 1683818146},
#  {'City': 'klyuchi',
#   'Lat': 52.2667,
#   'Lng': 79.1667,
#   'Max Temp': 290.06,
#   'Humidity': 45,
#   'Cloudiness': 3,
#   'Wind Speed': 7.55,
#   'Country': 'RU',
#   'Date': 1683818146},
#  {'City': 'nykobing sjaelland',
#   'Lat': 55.9249,
#   'Lng': 11.6711,
#   'Max Temp': 291.06,
#   'Humidity': 77,
#   'Cloudiness': 18,
#   'Wind Speed': 5.9,
#   'Country': 'DK',
#   'Date': 1683818146},
#  {'City': 'khandyga',
#   'Lat': 62.6667,
#   'Lng': 135.6,
#   'Max Temp': 274.16,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 0.32,
#   'Country': 'RU',
#   'Date': 1683818146},
#  {'City': 'salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 303.2,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 3.09,
#   'Country': 'OM',
#   'Date': 1683818146},
#  {'City': 'kudahuvadhoo',
#   'Lat': 2.6708,
#   'Lng': 72.8944,
#   'Max Temp': 301.23,
#   'Humidity': 78,
#   'Cloudiness': 98,
#   'Wind Speed': 6.93,
#   'Country': 'MV',
#   'Date': 1683818147},
#  {'City': 'mili',
#   'Lat': 6.0815,
#   'Lng': 171.735,
#   'Max Temp': 301.33,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 6.78,
#   'Country': 'MH',
#   'Date': 1683818147},
#  {'City': 'al kharijah',
#   'Lat': 25.4514,
#   'Lng': 30.5464,
#   'Max Temp': 312.47,
#   'Humidity': 7,
#   'Cloudiness': 0,
#   'Wind Speed': 7,
#   'Country': 'EG',
#   'Date': 1683818147},
#  {'City': 'san kamphaeng',
#   'Lat': 18.7449,
#   'Lng': 99.1195,
#   'Max Temp': 303.16,
#   'Humidity': 71,
#   'Cloudiness': 40,
#   'Wind Speed': 3.09,
#   'Country': 'TH',
#   'Date': 1683818147},
#  {'City': 'slave lake',
#   'Lat': 55.2834,
#   'Lng': -114.769,
#   'Max Temp': 287.24,
#   'Humidity': 60,
#   'Cloudiness': 98,
#   'Wind Speed': 3.06,
#   'Country': 'CA',
#   'Date': 1683818145},
#  {'City': 'bonthe',
#   'Lat': 7.5264,
#   'Lng': -12.505,
#   'Max Temp': 303.93,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 5.08,
#   'Country': 'SL',
#   'Date': 1683818148},
#  {'City': 'iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 266.87,
#   'Humidity': 79,
#   'Cloudiness': 18,
#   'Wind Speed': 6.71,
#   'Country': 'CA',
#   'Date': 1683818148},
#  {'City': 'vadso',
#   'Lat': 70.0744,
#   'Lng': 29.7487,
#   'Max Temp': 282.64,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Country': 'NO',
#   'Date': 1683818148},
#  {'City': 'odlabari',
#   'Lat': 26.8333,
#   'Lng': 88.6167,
#   'Max Temp': 298.95,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 3.81,
#   'Country': 'IN',
#   'Date': 1683818148},
#  {'City': 'cabo san lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 300.32,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Country': 'MX',
#   'Date': 1683818100},
#  {'City': 'olonkinbyen',
#   'Lat': 70.9221,
#   'Lng': -8.7187,
#   'Max Temp': 272.99,
#   'Humidity': 92,
#   'Cloudiness': 98,
#   'Wind Speed': 4.2,
#   'Country': 'SJ',
#   'Date': 1683818148},
#  {'City': 'debre tabor',
#   'Lat': 11.85,
#   'Lng': 38.0167,
#   'Max Temp': 294.62,
#   'Humidity': 33,
#   'Cloudiness': 62,
#   'Wind Speed': 0.43,
#   'Country': 'ET',
#   'Date': 1683818149},
#  {'City': 'stanley',
#   'Lat': 54.868,
#   'Lng': -1.6985,
#   'Max Temp': 288.44,
#   'Humidity': 72,
#   'Cloudiness': 20,
#   'Wind Speed': 3.6,
#   'Country': 'GB',
#   'Date': 1683818149},
#  {'City': 'balsas',
#   'Lat': -7.5325,
#   'Lng': -46.0356,
#   'Max Temp': 304.72,
#   'Humidity': 52,
#   'Cloudiness': 74,
#   'Wind Speed': 0.56,
#   'Country': 'BR',
#   'Date': 1683818149},
#  {'City': 'kotido',
#   'Lat': 2.9806,
#   'Lng': 34.1331,
#   'Max Temp': 300.19,
#   'Humidity': 47,
#   'Cloudiness': 94,
#   'Wind Speed': 5.75,
#   'Country': 'UG',
#   'Date': 1683818149},
#  {'City': 'remire-montjoly',
#   'Lat': 4.9167,
#   'Lng': -52.2667,
#   'Max Temp': 299.17,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 4.12,
#   'Country': 'GF',
#   'Date': 1683818149},
#  {'City': 'rio do sul',
#   'Lat': -27.2142,
#   'Lng': -49.6431,
#   'Max Temp': 295.59,
#   'Humidity': 40,
#   'Cloudiness': 1,
#   'Wind Speed': 1.68,
#   'Country': 'BR',
#   'Date': 1683818150},
#  {'City': 'kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 300.98,
#   'Humidity': 77,
#   'Cloudiness': 93,
#   'Wind Speed': 0.99,
#   'Country': 'PG',
#   'Date': 1683818150},
#  {'City': 'khovd',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': 287.96,
#   'Humidity': 39,
#   'Cloudiness': 97,
#   'Wind Speed': 1.1,
#   'Country': 'MN',
#   'Date': 1683818150},
#  {'City': 'coahuayana de hidalgo',
#   'Lat': 18.7,
#   'Lng': -103.6583,
#   'Max Temp': 303.1,
#   'Humidity': 59,
#   'Cloudiness': 22,
#   'Wind Speed': 0.74,
#   'Country': 'MX',
#   'Date': 1683818150},
#  {'City': 'kani keli',
#   'Lat': -12.9536,
#   'Lng': 45.1033,
#   'Max Temp': 301.74,
#   'Humidity': 71,
#   'Cloudiness': 15,
#   'Wind Speed': 0.94,
#   'Country': 'YT',
#   'Date': 1683818150},
#  {'City': 'thames',
#   'Lat': -37.1333,
#   'Lng': 175.5333,
#   'Max Temp': 279.65,
#   'Humidity': 94,
#   'Cloudiness': 21,
#   'Wind Speed': 2.77,
#   'Country': 'NZ',
#   'Date': 1683818150},
#  {'City': 'fale old settlement',
#   'Lat': -9.3852,
#   'Lng': -171.2468,
#   'Max Temp': 301.78,
#   'Humidity': 78,
#   'Cloudiness': 16,
#   'Wind Speed': 6.59,
#   'Country': 'TK',
#   'Date': 1683818156},
#  {'City': 'palikir - national government center',
#   'Lat': 6.9248,
#   'Lng': 158.1611,
#   'Max Temp': 301.22,
#   'Humidity': 80,
#   'Cloudiness': 54,
#   'Wind Speed': 4.2,
#   'Country': 'FM',
#   'Date': 1683818156},
#  {'City': 'mabaruma',
#   'Lat': 8.2,
#   'Lng': -59.7833,
#   'Max Temp': 302.78,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 2.63,
#   'Country': 'GY',
#   'Date': 1683818156},
#  {'City': 'kirensk',
#   'Lat': 57.7853,
#   'Lng': 108.1119,
#   'Max Temp': 274.61,
#   'Humidity': 64,
#   'Cloudiness': 11,
#   'Wind Speed': 0.94,
#   'Country': 'RU',
#   'Date': 1683818156},
#  {'City': 'mukalla',
#   'Lat': 14.5425,
#   'Lng': 49.1242,
#   'Max Temp': 302.85,
#   'Humidity': 69,
#   'Cloudiness': 71,
#   'Wind Speed': 3.23,
#   'Country': 'YE',
#   'Date': 1683818156},
#  {'City': 'yung shue wan',
#   'Lat': 22.2333,
#   'Lng': 114.1167,
#   'Max Temp': 298.47,
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 0.45,
#   'Country': 'HK',
#   'Date': 1683818157},
#  {'City': 'nadym',
#   'Lat': 65.5333,
#   'Lng': 72.5167,
#   'Max Temp': 266.27,
#   'Humidity': 83,
#   'Cloudiness': 61,
#   'Wind Speed': 3.65,
#   'Country': 'RU',
#   'Date': 1683818157},
#  {'City': 'jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 293.92,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'US',
#   'Date': 1683817972},
#  {'City': 'bel ombre',
#   'Lat': -4.6167,
#   'Lng': 55.4167,
#   'Max Temp': 301.06,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 4.12,
#   'Country': 'SC',
#   'Date': 1683818157},
#  {'City': 'garhi khairo',
#   'Lat': 28.0606,
#   'Lng': 67.9803,
#   'Max Temp': 312.79,
#   'Humidity': 5,
#   'Cloudiness': 25,
#   'Wind Speed': 1.9,
#   'Country': 'PK',
#   'Date': 1683818157},
#  {'City': 'mount gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 283.42,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.2,
#   'Country': 'AU',
#   'Date': 1683818158},
#  {'City': 'faya-largeau',
#   'Lat': 17.9257,
#   'Lng': 19.1043,
#   'Max Temp': 312.98,
#   'Humidity': 7,
#   'Cloudiness': 82,
#   'Wind Speed': 2.38,
#   'Country': 'TD',
#   'Date': 1683818158},
#  {'City': 'caconda',
#   'Lat': -13.7333,
#   'Lng': 15.0667,
#   'Max Temp': 298.57,
#   'Humidity': 24,
#   'Cloudiness': 5,
#   'Wind Speed': 3.04,
#   'Country': 'AO',
#   'Date': 1683818158},
#  {'City': 'perryville',
#   'Lat': 37.7242,
#   'Lng': -89.8612,
#   'Max Temp': 295.77,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': 1683818158},
#  {'City': 'puerto ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 301.13,
#   'Humidity': 100,
#   'Cloudiness': 74,
#   'Wind Speed': 2.24,
#   'Country': 'EC',
#   'Date': 1683817898},
#  {'City': 'minas de marcona',
#   'Lat': -15.2119,
#   'Lng': -75.1103,
#   'Max Temp': 291.96,
#   'Humidity': 64,
#   'Cloudiness': 21,
#   'Wind Speed': 3.44,
#   'Country': 'PE',
#   'Date': 1683818158},
#  {'City': 'codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 283.6,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 3.74,
#   'Country': 'AU',
#   'Date': 1683818159},
#  {'City': 'xilin hot',
#   'Lat': 43.9667,
#   'Lng': 116.0333,
#   'Max Temp': 282.28,
#   'Humidity': 73,
#   'Cloudiness': 94,
#   'Wind Speed': 2.12,
#   'Country': 'CN',
#   'Date': 1683818159},
#  {'City': 'punta arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 281.21,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Country': 'CL',
#   'Date': 1683818119},
#  {'City': 'andergrove',
#   'Lat': -21.0833,
#   'Lng': 149.1833,
#   'Max Temp': 294.06,
#   'Humidity': 81,
#   'Cloudiness': 21,
#   'Wind Speed': 6.2,
#   'Country': 'AU',
#   'Date': 1683818159},
#  {'City': 'mahina',
#   'Lat': -17.5065,
#   'Lng': -149.489,
#   'Max Temp': 299.02,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 6.17,
#   'Country': 'PF',
#   'Date': 1683818159},
#  {'City': 'chonchi',
#   'Lat': -42.6128,
#   'Lng': -73.8092,
#   'Max Temp': 287.66,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 0.99,
#   'Country': 'CL',
#   'Date': 1683818159},
#  {'City': 'arys',
#   'Lat': 42.4252,
#   'Lng': 68.795,
#   'Max Temp': 300.33,
#   'Humidity': 25,
#   'Cloudiness': 100,
#   'Wind Speed': 4.3,
#   'Country': 'KZ',
#   'Date': 1683818160},
#  {'City': 'novodvinsk',
#   'Lat': 64.4165,
#   'Lng': 40.8122,
#   'Max Temp': 287.13,
#   'Humidity': 49,
#   'Cloudiness': 100,
#   'Wind Speed': 4.36,
#   'Country': 'RU',
#   'Date': 1683818160},
#  {'City': 'pemangkat',
#   'Lat': 1.1667,
#   'Lng': 108.9667,
#   'Max Temp': 300.54,
#   'Humidity': 82,
#   'Cloudiness': 83,
#   'Wind Speed': 2.66,
#   'Country': 'ID',
#   'Date': 1683818160},
#  {'City': 'salinopolis',
#   'Lat': -0.6136,
#   'Lng': -47.3561,
#   'Max Temp': 302.22,
#   'Humidity': 68,
#   'Cloudiness': 82,
#   'Wind Speed': 3.65,
#   'Country': 'BR',
#   'Date': 1683818160},
#  {'City': 'namtsy',
#   'Lat': 62.7161,
#   'Lng': 129.6658,
#   'Max Temp': 271,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 4.66,
#   'Country': 'RU',
#   'Date': 1683818160},
#  {'City': 'kurchum',
#   'Lat': 48.5722,
#   'Lng': 83.6542,
#   'Max Temp': 293.65,
#   'Humidity': 34,
#   'Cloudiness': 100,
#   'Wind Speed': 2.49,
#   'Country': 'KZ',
#   'Date': 1683818161},
#  {'City': 'gbadolite',
#   'Lat': 4.2833,
#   'Lng': 21.0167,
#   'Max Temp': 299.21,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 2.41,
#   'Country': 'CD',
#   'Date': 1683818161},
#  {'City': 'tura',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 300.17,
#   'Humidity': 44,
#   'Cloudiness': 11,
#   'Wind Speed': 1.73,
#   'Country': 'IN',
#   'Date': 1683818161},
#  {'City': 'mount carmel',
#   'Lat': 38.4109,
#   'Lng': -87.7614,
#   'Max Temp': 295.12,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 2.75,
#   'Country': 'US',
#   'Date': 1683818161},
#  {'City': 'hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 296.48,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1683817563},
#  {'City': 'amvrosiyivka',
#   'Lat': 47.7935,
#   'Lng': 38.4777,
#   'Max Temp': 285.72,
#   'Humidity': 67,
#   'Cloudiness': 78,
#   'Wind Speed': 2.92,
#   'Country': 'UA',
#   'Date': 1683818162},
#  {'City': 'talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 258.82,
#   'Humidity': 84,
#   'Cloudiness': 19,
#   'Wind Speed': 6.26,
#   'Country': 'RU',
#   'Date': 1683818147},
#  {'City': 'iraquara',
#   'Lat': -12.2486,
#   'Lng': -41.6194,
#   'Max Temp': 306.41,
#   'Humidity': 35,
#   'Cloudiness': 54,
#   'Wind Speed': 0.94,
#   'Country': 'BR',
#   'Date': 1683818162},
#  {'City': 'afaahiti',
#   'Lat': -17.75,
#   'Lng': -149.2833,
#   'Max Temp': 298.08,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 11.93,
#   'Country': 'PF',
#   'Date': 1683818162},
#  {'City': 'nogliki',
#   'Lat': 51.8333,
#   'Lng': 143.1667,
#   'Max Temp': 273.48,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.13,
#   'Country': 'RU',
#   'Date': 1683818162},
#  {'City': 'cole harbour',
#   'Lat': 44.6724,
#   'Lng': -63.4751,
#   'Max Temp': 291.81,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 4.12,
#   'Country': 'CA',
#   'Date': 1683818163},
#  {'City': 'goz beida',
#   'Lat': 13.95,
#   'Lng': 20.55,
#   'Max Temp': 311.07,
#   'Humidity': 21,
#   'Cloudiness': 72,
#   'Wind Speed': 7.01,
#   'Country': 'TD',
#   'Date': 1683818163},
#  {'City': 'ke-macina',
#   'Lat': 13.9623,
#   'Lng': -5.3572,
#   'Max Temp': 315.17,
#   'Humidity': 7,
#   'Cloudiness': 100,
#   'Wind Speed': 3.3,
#   'Country': 'ML',
#   'Date': 1683818163},
#  {'City': 'thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 289.62,
#   'Humidity': 52,
#   'Cloudiness': 43,
#   'Wind Speed': 3.2,
#   'Country': 'CA',
#   'Date': 1683818163},
#  {'City': 'binuangan',
#   'Lat': 8.9153,
#   'Lng': 124.7883,
#   'Max Temp': 300.59,
#   'Humidity': 79,
#   'Cloudiness': 96,
#   'Wind Speed': 2.65,
#   'Country': 'PH',
#   'Date': 1683818163},
#  {'City': 'labrador city',
#   'Lat': 52.9463,
#   'Lng': -66.9114,
#   'Max Temp': 282.56,
#   'Humidity': 32,
#   'Cloudiness': 7,
#   'Wind Speed': 3.89,
#   'Country': 'CA',
#   'Date': 1683818163},
#  {'City': 'vilyuysk',
#   'Lat': 63.7553,
#   'Lng': 121.6247,
#   'Max Temp': 271.46,
#   'Humidity': 69,
#   'Cloudiness': 93,
#   'Wind Speed': 0.82,
#   'Country': 'RU',
#   'Date': 1683818164},
#  {'City': 'howrah',
#   'Lat': 22.5892,
#   'Lng': 88.3103,
#   'Max Temp': 304.15,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 6.17,
#   'Country': 'IN',
#   'Date': 1683818164},
#  {'City': 'tangalle',
#   'Lat': 6.024,
#   'Lng': 80.7911,
#   'Max Temp': 300.24,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 6.45,
#   'Country': 'LK',
#   'Date': 1683818164},
#  {'City': 'egilsstadir',
#   'Lat': 65.2653,
#   'Lng': -14.3948,
#   'Max Temp': 286.1,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 7.72,
#   'Country': 'IS',
#   'Date': 1683818164},
#  {'City': 'uturoa',
#   'Lat': -16.7333,
#   'Lng': -151.4333,
#   'Max Temp': 300.21,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 8.57,
#   'Country': 'PF',
#   'Date': 1683818151},
#  {'City': 'atherton',
#   'Lat': 53.5237,
#   'Lng': -2.4935,
#   'Max Temp': 289.48,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 1.79,
#   'Country': 'GB',
#   'Date': 1683818165},
#  {'City': 'chibougamau',
#   'Lat': 49.9168,
#   'Lng': -74.3659,
#   'Max Temp': 288.01,
#   'Humidity': 38,
#   'Cloudiness': 2,
#   'Wind Speed': 3.29,
#   'Country': 'CA',
#   'Date': 1683818165},
#  {'City': 'acapulco de juarez',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 303.05,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Country': 'MX',
#   'Date': 1683817965},
#  {'City': 'port alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 292.14,
#   'Humidity': 81,
#   'Cloudiness': 87,
#   'Wind Speed': 2.24,
#   'Country': 'ZA',
#   'Date': 1683818165},
#  {'City': 'saudarkrokur',
#   'Lat': 65.7461,
#   'Lng': -19.6394,
#   'Max Temp': 288.06,
#   'Humidity': 52,
#   'Cloudiness': 94,
#   'Wind Speed': 4.98,
#   'Country': 'IS',
#   'Date': 1683818166},
#  {'City': 'iskateley',
#   'Lat': 67.6803,
#   'Lng': 53.1512,
#   'Max Temp': 273.81,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 5.76,
#   'Country': 'RU',
#   'Date': 1683818166},
#  {'City': 'murun-kuren',
#   'Lat': 49.6342,
#   'Lng': 100.1625,
#   'Max Temp': 280.32,
#   'Humidity': 53,
#   'Cloudiness': 24,
#   'Wind Speed': 1.58,
#   'Country': 'MN',
#   'Date': 1683818166},
#  {'City': 'sedalia',
#   'Lat': 38.7045,
#   'Lng': -93.2283,
#   'Max Temp': 292.86,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.12,
#   'Country': 'US',
#   'Date': 1683818166},
#  {'City': 'hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 301.77,
#   'Humidity': 77,
#   'Cloudiness': 91,
#   'Wind Speed': 6.15,
#   'Country': 'MV',
#   'Date': 1683818171},
#  {'City': 'mount pearl',
#   'Lat': 47.5166,
#   'Lng': -52.7813,
#   'Max Temp': 283.96,
#   'Humidity': 46,
#   'Cloudiness': 40,
#   'Wind Speed': 9.77,
#   'Country': 'CA',
#   'Date': 1683818172},
#  {'City': 'kristiansund',
#   'Lat': 63.1115,
#   'Lng': 7.732,
#   'Max Temp': 285.51,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'NO',
#   'Date': 1683818172},
#  {'City': 'udachny',
#   'Lat': 66.4167,
#   'Lng': 112.4,
#   'Max Temp': 273.4,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 8.89,
#   'Country': 'RU',
#   'Date': 1683818172},
#  {'City': 'eisen',
#   'Lat': 36.8217,
#   'Lng': 128.6308,
#   'Max Temp': 283.92,
#   'Humidity': 67,
#   'Cloudiness': 6,
#   'Wind Speed': 0.96,
#   'Country': 'KR',
#   'Date': 1683818172},
#  {'City': 'kajiki',
#   'Lat': 31.7333,
#   'Lng': 130.6667,
#   'Max Temp': 288.51,
#   'Humidity': 84,
#   'Cloudiness': 87,
#   'Wind Speed': 1.45,
#   'Country': 'JP',
#   'Date': 1683818172},
#  {'City': 'crane',
#   'Lat': 31.3974,
#   'Lng': -102.3501,
#   'Max Temp': 296.3,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 6.43,
#   'Country': 'US',
#   'Date': 1683818161},
#  {'City': 'utrik',
#   'Lat': 11.2278,
#   'Lng': 169.8474,
#   'Max Temp': 300.55,
#   'Humidity': 80,
#   'Cloudiness': 98,
#   'Wind Speed': 8.14,
#   'Country': 'MH',
#   'Date': 1683818173},
#  {'City': 'saint-pierre',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 298.97,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Country': 'RE',
#   'Date': 1683818173},
#  {'City': 'atafu village',
#   'Lat': -8.5421,
#   'Lng': -172.5159,
#   'Max Temp': 301.98,
#   'Humidity': 76,
#   'Cloudiness': 13,
#   'Wind Speed': 6.52,
#   'Country': 'TK',
#   'Date': 1683818173},
#  {'City': 'vilyuchinsk',
#   'Lat': 52.9306,
#   'Lng': 158.4028,
#   'Max Temp': 274.3,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 5.29,
#   'Country': 'RU',
#   'Date': 1683818173},
#  {'City': 'tsiombe',
#   'Lat': -25.3,
#   'Lng': 45.4833,
#   'Max Temp': 297.57,
#   'Humidity': 77,
#   'Cloudiness': 87,
#   'Wind Speed': 2.61,
#   'Country': 'MG',
#   'Date': 1683818173},
#  {'City': 'debre sina',
#   'Lat': 9.85,
#   'Lng': 39.7667,
#   'Max Temp': 289.78,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 2.36,
#   'Country': 'ET',
#   'Date': 1683818173},
#  {'City': 'naryn',
#   'Lat': 41.4287,
#   'Lng': 75.9911,
#   'Max Temp': 286.2,
#   'Humidity': 32,
#   'Cloudiness': 10,
#   'Wind Speed': 4.31,
#   'Country': 'KG',
#   'Date': 1683818174},
#  {'City': 'port douglas',
#   'Lat': -16.4833,
#   'Lng': 145.4667,
#   'Max Temp': 295.42,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 4.11,
#   'Country': 'AU',
#   'Date': 1683818174},
#  {'City': 'luoyang',
#   'Lat': 34.6836,
#   'Lng': 112.4536,
#   'Max Temp': 291.77,
#   'Humidity': 58,
#   'Cloudiness': 18,
#   'Wind Speed': 2.25,
#   'Country': 'CN',
#   'Date': 1683818174},
#  {'City': 'sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 306.29,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 1.5,
#   'Country': 'OM',
#   'Date': 1683818174},
#  {'City': 'bandar abbas',
#   'Lat': 27.1865,
#   'Lng': 56.2808,
#   'Max Temp': 310.14,
#   'Humidity': 23,
#   'Cloudiness': 79,
#   'Wind Speed': 4.12,
#   'Country': 'IR',
#   'Date': 1683818174},
#  {'City': 'nova vicosa',
#   'Lat': -17.8919,
#   'Lng': -39.3719,
#   'Max Temp': 300.28,
#   'Humidity': 65,
#   'Cloudiness': 69,
#   'Wind Speed': 2.85,
#   'Country': 'BR',
#   'Date': 1683818173},
#  {'City': 'calvinia',
#   'Lat': -31.4707,
#   'Lng': 19.776,
#   'Max Temp': 288.03,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 4.51,
#   'Country': 'ZA',
#   'Date': 1683818175},
#  {'City': 'donvale',
#   'Lat': -37.7891,
#   'Lng': 145.1749,
#   'Max Temp': 285.69,
#   'Humidity': 88,
#   'Cloudiness': 42,
#   'Wind Speed': 2.22,
#   'Country': 'AU',
#   'Date': 1683818175},
#  {'City': 'ad dilam',
#   'Lat': 23.9915,
#   'Lng': 47.1627,
#   'Max Temp': 311.2,
#   'Humidity': 8,
#   'Cloudiness': 7,
#   'Wind Speed': 3.65,
#   'Country': 'SA',
#   'Date': 1683818175},
#  {'City': 'selfoss',
#   'Lat': 63.9331,
#   'Lng': -20.9971,
#   'Max Temp': 282.62,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 6.01,
#   'Country': 'IS',
#   'Date': 1683818175},
#  {'City': 'kayangel',
#   'Lat': 8.0823,
#   'Lng': 134.7173,
#   'Max Temp': 302.06,
#   'Humidity': 71,
#   'Cloudiness': 93,
#   'Wind Speed': 1.32,
#   'Country': 'PW',
#   'Date': 1683818175},
#  {'City': 'kaihua',
#   'Lat': 23.3687,
#   'Lng': 104.28,
#   'Max Temp': 290.69,
#   'Humidity': 86,
#   'Cloudiness': 98,
#   'Wind Speed': 3.28,
#   'Country': 'CN',
#   'Date': 1683818176},
#  {'City': 'polyarnyy',
#   'Lat': 69.1989,
#   'Lng': 33.4478,
#   'Max Temp': 277.31,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.27,
#   'Country': 'RU',
#   'Date': 1683818176},
#  {'City': 'inhambane',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 298.14,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 4.12,
#   'Country': 'MZ',
#   'Date': 1683818176},
#  {'City': 'nemuro',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 276.45,
#   'Humidity': 83,
#   'Cloudiness': 27,
#   'Wind Speed': 5.59,
#   'Country': 'JP',
#   'Date': 1683818176},
#  {'City': 'sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 284.09,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': 1683818012},
#  {'City': 'turan',
#   'Lat': 16.0678,
#   'Lng': 108.2208,
#   'Max Temp': 299.14,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 0.51,
#   'Country': 'VN',
#   'Date': 1683818176},
#  {'City': 'papao',
#   'Lat': -17.75,
#   'Lng': -149.55,
#   'Max Temp': 298.97,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 14.15,
#   'Country': 'PF',
#   'Date': 1683818177},
#  {'City': 'robel',
#   'Lat': 53.3755,
#   'Lng': 12.6037,
#   'Max Temp': 290.72,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 3.65,
#   'Country': 'DE',
#   'Date': 1683818177},
#  {'City': 'ray',
#   'Lat': 23.6833,
#   'Lng': 85.05,
#   'Max Temp': 305.58,
#   'Humidity': 9,
#   'Cloudiness': 82,
#   'Wind Speed': 3.3,
#   'Country': 'IN',
#   'Date': 1683818177},
#  {'City': 'pointe-noire',
#   'Lat': -4.7761,
#   'Lng': 11.8635,
#   'Max Temp': 301.75,
#   'Humidity': 77,
#   'Cloudiness': 76,
#   'Wind Speed': 3.33,
#   'Country': 'CG',
#   'Date': 1683818177},
#  {'City': 'tallulah',
#   'Lat': 32.4085,
#   'Lng': -91.1868,
#   'Max Temp': 299.15,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': 1683817914},
#  {'City': "taman'",
#   'Lat': 45.2117,
#   'Lng': 36.7161,
#   'Max Temp': 285.33,
#   'Humidity': 55,
#   'Cloudiness': 1,
#   'Wind Speed': 4.18,
#   'Country': 'RU',
#   'Date': 1683818177},
#  {'City': 'tanda',
#   'Lat': 26.55,
#   'Lng': 82.65,
#   'Max Temp': 306.62,
#   'Humidity': 8,
#   'Cloudiness': 0,
#   'Wind Speed': 2.49,
#   'Country': 'IN',
#   'Date': 1683818178},
#  {'City': 'cabedelo',
#   'Lat': -6.9811,
#   'Lng': -34.8339,
#   'Max Temp': 304.52,
#   'Humidity': 66,
#   'Cloudiness': 49,
#   'Wind Speed': 3.68,
#   'Country': 'BR',
#   'Date': 1683818178},
#  {'City': 'ashburton',
#   'Lat': -37.8626,
#   'Lng': 145.0794,
#   'Max Temp': 286.14,
#   'Humidity': 85,
#   'Cloudiness': 48,
#   'Wind Speed': 3.71,
#   'Country': 'AU',
#   'Date': 1683818178},
#  {'City': 'labasa',
#   'Lat': -16.4167,
#   'Lng': 179.3833,
#   'Max Temp': 297.59,
#   'Humidity': 92,
#   'Cloudiness': 22,
#   'Wind Speed': 2.27,
#   'Country': 'FJ',
#   'Date': 1683818178},
#  {'City': 'happy valley-goose bay',
#   'Lat': 53.3168,
#   'Lng': -60.3315,
#   'Max Temp': 281.32,
#   'Humidity': 27,
#   'Cloudiness': 40,
#   'Wind Speed': 5.66,
#   'Country': 'CA',
#   'Date': 1683818178},
#  {'City': 'queenstown',
#   'Lat': -31.8976,
#   'Lng': 26.8753,
#   'Max Temp': 294.84,
#   'Humidity': 22,
#   'Cloudiness': 26,
#   'Wind Speed': 2.9,
#   'Country': 'ZA',
#   'Date': 1683818178},
#  {'City': 'aasiaat',
#   'Lat': 68.7098,
#   'Lng': -52.8699,
#   'Max Temp': 270.05,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 2.34,
#   'Country': 'GL',
#   'Date': 1683818179},
#  {'City': 'alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 299.17,
#   'Humidity': 82,
#   'Cloudiness': 13,
#   'Wind Speed': 8.18,
#   'Country': 'NU',
#   'Date': 1683817895},
#  {'City': 'rouissat',
#   'Lat': 31.9243,
#   'Lng': 5.3502,
#   'Max Temp': 309.19,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 6.17,
#   'Country': 'DZ',
#   'Date': 1683818179},
#  {'City': "nar'yan-mar",
#   'Lat': 67.6713,
#   'Lng': 53.087,
#   'Max Temp': 273.77,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 5.89,
#   'Country': 'RU',
#   'Date': 1683818179},
#  {'City': 'hawaiian paradise park',
#   'Lat': 19.5933,
#   'Lng': -154.9731,
#   'Max Temp': 293.88,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': 1683818166},
#  {'City': 'arraial do cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 298.07,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 2.57,
#   'Country': 'BR',
#   'Date': 1683818180},
#  {'City': 'los alamos',
#   'Lat': 35.8881,
#   'Lng': -106.307,
#   'Max Temp': 284.48,
#   'Humidity': 37,
#   'Cloudiness': 75,
#   'Wind Speed': 5.66,
#   'Country': 'US',
#   'Date': 1683818149},
#  {'City': 'kimbe',
#   'Lat': -5.5502,
#   'Lng': 150.1429,
#   'Max Temp': 298.01,
#   'Humidity': 95,
#   'Cloudiness': 98,
#   'Wind Speed': 1.26,
#   'Country': 'PG',
#   'Date': 1683818180},
#  {'City': 'pimentel',
#   'Lat': -6.8367,
#   'Lng': -79.9342,
#   'Max Temp': 300.31,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 7.72,
#   'Country': 'PE',
#   'Date': 1683818180},
#  {'City': 'aleksandrovsk',
#   'Lat': 59.158,
#   'Lng': 57.5624,
#   'Max Temp': 283.28,
#   'Humidity': 52,
#   'Cloudiness': 20,
#   'Wind Speed': 0.89,
#   'Country': 'RU',
#   'Date': 1683818180},
#  {'City': "cooper's town",
#   'Lat': 26.8667,
#   'Lng': -77.5167,
#   'Max Temp': 298.22,
#   'Humidity': 69,
#   'Cloudiness': 5,
#   'Wind Speed': 5.49,
#   'Country': 'BS',
#   'Date': 1683818181},
#  {'City': 'luanda',
#   'Lat': -8.8368,
#   'Lng': 13.2343,
#   'Max Temp': 305.15,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 6.69,
#   'Country': 'AO',
#   'Date': 1683818127},
#  {'City': 'alice springs',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 278.9,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 3.23,
#   'Country': 'AU',
#   'Date': 1683818181},
#  {'City': 'yeppoon',
#   'Lat': -23.1333,
#   'Lng': 150.7333,
#   'Max Temp': 292.03,
#   'Humidity': 76,
#   'Cloudiness': 2,
#   'Wind Speed': 7.11,
#   'Country': 'AU',
#   'Date': 1683818181},
#  {'City': 'ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 286.78,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.32,
#   'Country': 'CL',
#   'Date': 1683818181},
#  {'City': 'columbia falls',
#   'Lat': 48.3725,
#   'Lng': -114.1815,
#   'Max Temp': 284.49,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'US',
#   'Date': 1683818026},
#  {'City': 'pacific grove',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 286.21,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 5.81,
#   'Country': 'US',
#   'Date': 1683818182},
#  {'City': 'tual',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp': 300.96,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 9.8,
#   'Country': 'ID',
#   'Date': 1683818182},
#  {'City': 'praia da vitoria',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 293.57,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 6.37,
#   'Country': 'PT',
#   'Date': 1683818182},
#  {'City': 'puerto real',
#   'Lat': 36.5282,
#   'Lng': -6.1901,
#   'Max Temp': 301.82,
#   'Humidity': 64,
#   'Cloudiness': 20,
#   'Wind Speed': 5.66,
#   'Country': 'ES',
#   'Date': 1683818182},
#  {'City': 'laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 287.83,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': 1683818183},
#  {'City': "n'dalatando",
#   'Lat': -9.2978,
#   'Lng': 14.9116,
#   'Max Temp': 302.71,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 1.18,
#   'Country': 'AO',
#   'Date': 1683818183},
#  {'City': 'ain sefra',
#   'Lat': 32.75,
#   'Lng': -0.5833,
#   'Max Temp': 303.98,
#   'Humidity': 14,
#   'Cloudiness': 74,
#   'Wind Speed': 4.8,
#   'Country': 'DZ',
#   'Date': 1683818183},
#  {'City': 'geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 287.38,
#   'Humidity': 54,
#   'Cloudiness': 2,
#   'Wind Speed': 4.63,
#   'Country': 'AU',
#   'Date': 1683818183},
#  {'City': 'douz',
#   'Lat': 33.4663,
#   'Lng': 9.0203,
#   'Max Temp': 304.61,
#   'Humidity': 20,
#   'Cloudiness': 99,
#   'Wind Speed': 5.12,
#   'Country': 'TN',
#   'Date': 1683818183},
#  {'City': 'san isidro',
#   'Lat': -12.1167,
#   'Lng': -77.05,
#   'Max Temp': 297.6,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Country': 'PE',
#   'Date': 1683818184},
#  {'City': 'dhidhdhoo',
#   'Lat': 6.8833,
#   'Lng': 73.1,
#   'Max Temp': 302.46,
#   'Humidity': 73,
#   'Cloudiness': 94,
#   'Wind Speed': 3.54,
#   'Country': 'MV',
#   'Date': 1683818184},
#  {'City': 'mananjary',
#   'Lat': -21.2167,
#   'Lng': 48.3333,
#   'Max Temp': 297,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'MG',
#   'Date': 1683818184},
#  {'City': 'minehead',
#   'Lat': 51.2057,
#   'Lng': -3.4788,
#   'Max Temp': 289.69,
#   'Humidity': 78,
#   'Cloudiness': 9,
#   'Wind Speed': 2.68,
#   'Country': 'GB',
#   'Date': 1683818184},
#  {'City': 'broken hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 283.79,
#   'Humidity': 52,
#   'Cloudiness': 12,
#   'Wind Speed': 0.77,
#   'Country': 'AU',
#   'Date': 1683818184},
#  {'City': 'coquimbo',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 286,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.03,
#   'Country': 'CL',
#   'Date': 1683818184},
#  {'City': 'mermoz boabab',
#   'Lat': 14.7065,
#   'Lng': -17.4758,
#   'Max Temp': 304.46,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 7.2,
#   'Country': 'SN',
#   'Date': 1683818185},
#  {'City': 'san pedro',
#   'Lat': 14.35,
#   'Lng': 121.0167,
#   'Max Temp': 301.72,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 3.09,
#   'Country': 'PH',
#   'Date': 1683817908},
#  {'City': 'hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 295.5,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 0.2,
#   'Country': 'CN',
#   'Date': 1683818185},
#  {'City': 'big bend',
#   'Lat': -26.8167,
#   'Lng': 31.9333,
#   'Max Temp': 295.91,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 1.21,
#   'Country': 'SZ',
#   'Date': 1683818185},
#  {'City': 'mitsamiouli',
#   'Lat': -11.3847,
#   'Lng': 43.2844,
#   'Max Temp': 300.23,
#   'Humidity': 73,
#   'Cloudiness': 10,
#   'Wind Speed': 1.8,
#   'Country': 'KM',
#   'Date': 1683818185},
#  {'City': "arkhangel'sk",
#   'Lat': 64.5401,
#   'Lng': 40.5433,
#   'Max Temp': 286.17,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 3.71,
#   'Country': 'RU',
#   'Date': 1683818186},
#  {'City': 'jiayuguan',
#   'Lat': 39.8167,
#   'Lng': 98.3,
#   'Max Temp': 288.99,
#   'Humidity': 13,
#   'Cloudiness': 5,
#   'Wind Speed': 5.8,
#   'Country': 'CN',
#   'Date': 1683818186},
#  {'City': 'ispica',
#   'Lat': 36.7844,
#   'Lng': 14.9063,
#   'Max Temp': 293.5,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 8.17,
#   'Country': 'IT',
#   'Date': 1683818186},
#  {'City': 'colonia',
#   'Lat': 50.9333,
#   'Lng': 6.95,
#   'Max Temp': 291.46,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 4.12,
#   'Country': 'DE',
#   'Date': 1683817896},
#  {'City': 'vila velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 300.12,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 5.66,
#   'Country': 'BR',
#   'Date': 1683818101},
#  {'City': 'port said',
#   'Lat': 31.2565,
#   'Lng': 32.2841,
#   'Max Temp': 294.35,
#   'Humidity': 78,
#   'Cloudiness': 68,
#   'Wind Speed': 11.24,
#   'Country': 'EG',
#   'Date': 1683818186},
#  {'City': 'lamu',
#   'Lat': -2.2717,
#   'Lng': 40.902,
#   'Max Temp': 301.27,
#   'Humidity': 82,
#   'Cloudiness': 62,
#   'Wind Speed': 5.02,
#   'Country': 'KE',
#   'Date': 1683818187},
#  {'City': 'lahaina',
#   'Lat': 20.8783,
#   'Lng': -156.6825,
#   'Max Temp': 295.26,
#   'Humidity': 89,
#   'Cloudiness': 96,
#   'Wind Speed': 2.77,
#   'Country': 'US',
#   'Date': 1683818187},
#  {'City': 'mhamid',
#   'Lat': 29.82,
#   'Lng': -5.72,
#   'Max Temp': 312.95,
#   'Humidity': 5,
#   'Cloudiness': 1,
#   'Wind Speed': 8.23,
#   'Country': 'MA',
#   'Date': 1683818187},
#  {'City': 'kandiari',
#   'Lat': 26.9156,
#   'Lng': 68.5216,
#   'Max Temp': 314.33,
#   'Humidity': 7,
#   'Cloudiness': 1,
#   'Wind Speed': 1.62,
#   'Country': 'PK',
#   'Date': 1683818187},
#  {'City': 'mar del plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 286.45,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Country': 'AR',
#   'Date': 1683817943},
#  {'City': 'yeosu',
#   'Lat': 34.7546,
#   'Lng': 127.6599,
#   'Max Temp': 288.81,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Country': 'KR',
#   'Date': 1683817937},
#  {'City': 'mirante do paranapanema',
#   'Lat': -22.2919,
#   'Lng': -51.9064,
#   'Max Temp': 294.8,
#   'Humidity': 51,
#   'Cloudiness': 26,
#   'Wind Speed': 3.34,
#   'Country': 'BR',
#   'Date': 1683818188},
#  {'City': 'mawu',
#   'Lat': 29.5923,
#   'Lng': 107.3139,
#   'Max Temp': 287.66,
#   'Humidity': 92,
#   'Cloudiness': 57,
#   'Wind Speed': 1.17,
#   'Country': 'CN',
#   'Date': 1683818188},
#  {'City': 'whitecourt',
#   'Lat': 54.1502,
#   'Lng': -115.6855,
#   'Max Temp': 282.73,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 1.54,
#   'Country': 'CA',
#   'Date': 1683818188},
#  {'City': 'okondja',
#   'Lat': -0.6549,
#   'Lng': 13.6753,
#   'Max Temp': 304.01,
#   'Humidity': 58,
#   'Cloudiness': 73,
#   'Wind Speed': 0.49,
#   'Country': 'GA',
#   'Date': 1683818188},
#  {'City': 'sheridan',
#   'Lat': 44.8333,
#   'Lng': -106.9173,
#   'Max Temp': 283.88,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1683818188},
#  {'City': 'merritt',
#   'Lat': 50.1123,
#   'Lng': -120.7942,
#   'Max Temp': 283.89,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 1.06,
#   'Country': 'CA',
#   'Date': 1683818189},
#  {'City': 'villa nueva',
#   'Lat': 14.5269,
#   'Lng': -90.5875,
#   'Max Temp': 297.16,
#   'Humidity': 70,
# ...
#   'Lat': 6.6221,
#   'Lng': 73.07,
#   'Max Temp': 302.25,
#   'Humidity': 74,
#   'Cloudiness': 92,
#   'Wind Speed': 3.53,
#   'Country': 'MV',
#   'Date': 1683818238},
#  {'City': 'porto novo',
#   'Lat': 6.4965,
#   'Lng': 2.6036,
#   'Max Temp': 306.05,
#   'Humidity': 61,
#   'Cloudiness': 64,
#   'Wind Speed': 4.94,
#   'Country': 'BJ',
#   'Date': 1683818239},
#  {'City': "k'olito",
#   'Lat': 7.3167,
#   'Lng': 38.0833,
#   'Max Temp': 295.18,
#   'Humidity': 68,
#   'Cloudiness': 99,
#   'Wind Speed': 1.72,
#   'Country': 'ET',
#   'Date': 1683818239},
#  {'City': 'gaspe',
#   'Lat': 48.8334,
#   'Lng': -64.4819,
#   'Max Temp': 286.27,
#   'Humidity': 35,
#   'Cloudiness': 20,
#   'Wind Speed': 5.14,
#   'Country': 'CA',
#   'Date': 1683818239},
#  {'City': 'flin flon',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp': 290.06,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'CA',
#   'Date': 1683818210},
#  {'City': 'tolanaro',
#   'Lat': -25.0319,
#   'Lng': 46.9987,
#   'Max Temp': 297.3,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 5.06,
#   'Country': 'MG',
#   'Date': 1683818239},
#  {'City': 'kagoro',
#   'Lat': 9.6,
#   'Lng': 8.3833,
#   'Max Temp': 308.05,
#   'Humidity': 26,
#   'Cloudiness': 40,
#   'Wind Speed': 3.41,
#   'Country': 'NG',
#   'Date': 1683818239},
#  {'City': 'fremont',
#   'Lat': 37.5483,
#   'Lng': -121.9886,
#   'Max Temp': 286.48,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': 1683818240},
#  {'City': 'tshela',
#   'Lat': -4.9833,
#   'Lng': 12.9333,
#   'Max Temp': 305.71,
#   'Humidity': 54,
#   'Cloudiness': 59,
#   'Wind Speed': 1.12,
#   'Country': 'CD',
#   'Date': 1683818240},
#  {'City': 'ranau',
#   'Lat': 5.9538,
#   'Lng': 116.6641,
#   'Max Temp': 295.7,
#   'Humidity': 98,
#   'Cloudiness': 54,
#   'Wind Speed': 0.33,
#   'Country': 'MY',
#   'Date': 1683818240},
#  {'City': 'masterton',
#   'Lat': -40.9597,
#   'Lng': 175.6575,
#   'Max Temp': 276.95,
#   'Humidity': 94,
#   'Cloudiness': 22,
#   'Wind Speed': 1.43,
#   'Country': 'NZ',
#   'Date': 1683818240},
#  {'City': 'whakatane',
#   'Lat': -37.9585,
#   'Lng': 176.9854,
#   'Max Temp': 281.91,
#   'Humidity': 98,
#   'Cloudiness': 79,
#   'Wind Speed': 0.45,
#   'Country': 'NZ',
#   'Date': 1683818240},
#  {'City': 'rawson',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 291.62,
#   'Humidity': 41,
#   'Cloudiness': 5,
#   'Wind Speed': 5.28,
#   'Country': 'AR',
#   'Date': 1683818241},
#  {'City': 'cinarcik',
#   'Lat': 40.6412,
#   'Lng': 29.146,
#   'Max Temp': 285.62,
#   'Humidity': 75,
#   'Cloudiness': 91,
#   'Wind Speed': 8.18,
#   'Country': 'TR',
#   'Date': 1683818241},
#  {'City': 'cushing',
#   'Lat': 35.9851,
#   'Lng': -96.767,
#   'Max Temp': 295.51,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': 1683818188},
#  {'City': 'saquarema',
#   'Lat': -22.92,
#   'Lng': -42.5103,
#   'Max Temp': 298.17,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 2.85,
#   'Country': 'BR',
#   'Date': 1683818241},
#  {'City': 'luganville',
#   'Lat': -15.5333,
#   'Lng': 167.1667,
#   'Max Temp': 298.54,
#   'Humidity': 85,
#   'Cloudiness': 64,
#   'Wind Speed': 5.89,
#   'Country': 'VU',
#   'Date': 1683818070},
#  {'City': 'kineshma',
#   'Lat': 57.4391,
#   'Lng': 42.1289,
#   'Max Temp': 289.08,
#   'Humidity': 54,
#   'Cloudiness': 65,
#   'Wind Speed': 2.28,
#   'Country': 'RU',
#   'Date': 1683818241},
#  {'City': 'devils lake',
#   'Lat': 48.1128,
#   'Lng': -98.8651,
#   'Max Temp': 292.21,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 5.66,
#   'Country': 'US',
#   'Date': 1683818242},
#  {'City': 'haiku-pauwela',
#   'Lat': 20.9219,
#   'Lng': -156.3051,
#   'Max Temp': 293.73,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'US',
#   'Date': 1683818242},
#  {'City': 'ad dabbah',
#   'Lat': 18.05,
#   'Lng': 30.95,
#   'Max Temp': 315.85,
#   'Humidity': 6,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'SD',
#   'Date': 1683818242},
#  {'City': 'linxi',
#   'Lat': 39.7,
#   'Lng': 118.4333,
#   'Max Temp': 292.61,
#   'Humidity': 28,
#   'Cloudiness': 98,
#   'Wind Speed': 3.8,
#   'Country': 'CN',
#   'Date': 1683818242},
#  {'City': 'la ronge',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': 291.27,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Country': 'CA',
#   'Date': 1683818242},
#  {'City': 'araguaina',
#   'Lat': -7.1911,
#   'Lng': -48.2072,
#   'Max Temp': 305.89,
#   'Humidity': 48,
#   'Cloudiness': 38,
#   'Wind Speed': 0.54,
#   'Country': 'BR',
#   'Date': 1683818242},
#  {'City': 'santiago de cuba',
#   'Lat': 20.0247,
#   'Lng': -75.8219,
#   'Max Temp': 303.21,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 2.57,
#   'Country': 'CU',
#   'Date': 1683818243},
#  {'City': 'bodaybo',
#   'Lat': 57.8506,
#   'Lng': 114.1933,
#   'Max Temp': 271.13,
#   'Humidity': 97,
#   'Cloudiness': 80,
#   'Wind Speed': 0.09,
#   'Country': 'RU',
#   'Date': 1683818208},
#  {'City': 'tamiahua',
#   'Lat': 21.2667,
#   'Lng': -97.45,
#   'Max Temp': 302.82,
#   'Humidity': 72,
#   'Cloudiness': 26,
#   'Wind Speed': 2.84,
#   'Country': 'MX',
#   'Date': 1683818243},
#  {'City': 'liepaja',
#   'Lat': 56.5419,
#   'Lng': 21.0367,
#   'Max Temp': 291.14,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'LV',
#   'Date': 1683818243},
#  {'City': 'paramonga',
#   'Lat': -10.6667,
#   'Lng': -77.8333,
#   'Max Temp': 296.38,
#   'Humidity': 79,
#   'Cloudiness': 95,
#   'Wind Speed': 3.5,
#   'Country': 'PE',
#   'Date': 1683818243},
#  {'City': 'sierra grande',
#   'Lat': -41.606,
#   'Lng': -65.3557,
#   'Max Temp': 287.53,
#   'Humidity': 62,
#   'Cloudiness': 41,
#   'Wind Speed': 3.13,
#   'Country': 'AR',
#   'Date': 1683818243},
#  {'City': 'dunedin',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 284.15,
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 5.36,
#   'Country': 'NZ',
#   'Date': 1683818244},
#  {'City': 'makinsk',
#   'Lat': 52.6292,
#   'Lng': 70.4169,
#   'Max Temp': 285.2,
#   'Humidity': 59,
#   'Cloudiness': 46,
#   'Wind Speed': 6.28,
#   'Country': 'KZ',
#   'Date': 1683818244},
#  {'City': 'viedma',
#   'Lat': -40.8135,
#   'Lng': -62.9967,
#   'Max Temp': 289.72,
#   'Humidity': 34,
#   'Cloudiness': 14,
#   'Wind Speed': 8.15,
#   'Country': 'AR',
#   'Date': 1683818244},
#  {'City': 'horodnytsya',
#   'Lat': 50.807,
#   'Lng': 27.3168,
#   'Max Temp': 287.38,
#   'Humidity': 41,
#   'Cloudiness': 47,
#   'Wind Speed': 3.16,
#   'Country': 'UA',
#   'Date': 1683818244},
#  {'City': 'saint-louis',
#   'Lat': 16.3333,
#   'Lng': -15,
#   'Max Temp': 315.9,
#   'Humidity': 7,
#   'Cloudiness': 29,
#   'Wind Speed': 5.79,
#   'Country': 'SN',
#   'Date': 1683818244},
#  {'City': 'sao joao da barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 297.2,
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 3.47,
#   'Country': 'BR',
#   'Date': 1683818244},
#  {'City': 'nantucket',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp': 294.9,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 6.17,
#   'Country': 'US',
#   'Date': 1683818245},
#  {'City': 'san patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 302.07,
#   'Humidity': 78,
#   'Cloudiness': 57,
#   'Wind Speed': 7.09,
#   'Country': 'US',
#   'Date': 1683818245},
#  {'City': 'soe',
#   'Lat': -9.8607,
#   'Lng': 124.284,
#   'Max Temp': 290.7,
#   'Humidity': 96,
#   'Cloudiness': 97,
#   'Wind Speed': 2.13,
#   'Country': 'ID',
#   'Date': 1683818241},
#  {'City': 'blenheim',
#   'Lat': -41.516,
#   'Lng': 173.9528,
#   'Max Temp': 274,
#   'Humidity': 87,
#   'Cloudiness': 11,
#   'Wind Speed': 3.32,
#   'Country': 'NZ',
#   'Date': 1683818245},
#  {'City': 'callao',
#   'Lat': -12.0667,
#   'Lng': -77.15,
#   'Max Temp': 298.55,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Country': 'PE',
#   'Date': 1683818245},
#  {'City': 'malanje',
#   'Lat': -9.5402,
#   'Lng': 16.341,
#   'Max Temp': 299.62,
#   'Humidity': 41,
#   'Cloudiness': 1,
#   'Wind Speed': 1.58,
#   'Country': 'AO',
#   'Date': 1683818245},
#  {'City': 'hun',
#   'Lat': 29.1268,
#   'Lng': 15.9477,
#   'Max Temp': 302.12,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 6.54,
#   'Country': 'LY',
#   'Date': 1683818246},
#  {'City': 'la passe',
#   'Lat': 45.5549,
#   'Lng': -0.8967,
#   'Max Temp': 288.7,
#   'Humidity': 59,
#   'Cloudiness': 19,
#   'Wind Speed': 6.82,
#   'Country': 'FR',
#   'Date': 1683818246},
#  {'City': 'benguela',
#   'Lat': -12.5763,
#   'Lng': 13.4055,
#   'Max Temp': 302.42,
#   'Humidity': 68,
#   'Cloudiness': 19,
#   'Wind Speed': 5.56,
#   'Country': 'AO',
#   'Date': 1683818246},
#  {'City': 'gereida',
#   'Lat': 11.2811,
#   'Lng': 25.1414,
#   'Max Temp': 313.18,
#   'Humidity': 14,
#   'Cloudiness': 89,
#   'Wind Speed': 3.09,
#   'Country': 'SD',
#   'Date': 1683818246},
#  {'City': 'las heras',
#   'Lat': -46.5419,
#   'Lng': -68.9359,
#   'Max Temp': 286.32,
#   'Humidity': 55,
#   'Cloudiness': 36,
#   'Wind Speed': 7.59,
#   'Country': 'AR',
#   'Date': 1683818246},
#  {'City': 'morehead',
#   'Lat': 37.2711,
#   'Lng': -87.1764,
#   'Max Temp': 294.26,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1683818246},
#  {'City': 'luwuk',
#   'Lat': -0.9516,
#   'Lng': 122.7875,
#   'Max Temp': 298.96,
#   'Humidity': 85,
#   'Cloudiness': 32,
#   'Wind Speed': 2.15,
#   'Country': 'ID',
#   'Date': 1683818247},
#  {'City': 'vila franca do campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 291.38,
#   'Humidity': 80,
#   'Cloudiness': 80,
#   'Wind Speed': 2.86,
#   'Country': 'PT',
#   'Date': 1683818247},
#  {'City': 'touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 303.12,
#   'Humidity': 59,
#   'Cloudiness': 26,
#   'Wind Speed': 5.36,
#   'Country': 'BR',
#   'Date': 1683818149},
#  {'City': 'hovd',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': 287.96,
#   'Humidity': 39,
#   'Cloudiness': 97,
#   'Wind Speed': 1.1,
#   'Country': 'MN',
#   'Date': 1683818176},
#  {'City': 'am timan',
#   'Lat': 11.0297,
#   'Lng': 20.2827,
#   'Max Temp': 309.24,
#   'Humidity': 28,
#   'Cloudiness': 59,
#   'Wind Speed': 3.86,
#   'Country': 'TD',
#   'Date': 1683818247},
#  {'City': 'cockburn town',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 299.93,
#   'Humidity': 77,
#   'Cloudiness': 89,
#   'Wind Speed': 5.65,
#   'Country': 'TC',
#   'Date': 1683818247},
#  {'City': 'castillos',
#   'Lat': -34.1667,
#   'Lng': -53.8333,
#   'Max Temp': 290.51,
#   'Humidity': 59,
#   'Cloudiness': 59,
#   'Wind Speed': 4,
#   'Country': 'UY',
#   'Date': 1683818145},
#  {'City': 'camarinas',
#   'Lat': 43.1311,
#   'Lng': -9.1817,
#   'Max Temp': 293.11,
#   'Humidity': 64,
#   'Cloudiness': 1,
#   'Wind Speed': 6.29,
#   'Country': 'ES',
#   'Date': 1683818248},
#  {'City': 'sanctuary point',
#   'Lat': -35.1114,
#   'Lng': 150.629,
#   'Max Temp': 289.44,
#   'Humidity': 85,
#   'Cloudiness': 3,
#   'Wind Speed': 2.72,
#   'Country': 'AU',
#   'Date': 1683818248},
#  {'City': 'chos malal',
#   'Lat': -37.3781,
#   'Lng': -70.2709,
#   'Max Temp': 291.14,
#   'Humidity': 33,
#   'Cloudiness': 96,
#   'Wind Speed': 2.23,
#   'Country': 'AR',
#   'Date': 1683818248},
#  {'City': 'les avirons',
#   'Lat': -21.2418,
#   'Lng': 55.3394,
#   'Max Temp': 297.2,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Country': 'RE',
#   'Date': 1683818248},
#  {'City': 'bloomfield',
#   'Lat': 40.8068,
#   'Lng': -74.1854,
#   'Max Temp': 298.32,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'US',
#   'Date': 1683818248},
#  {'City': 'riedering',
#   'Lat': 47.8333,
#   'Lng': 12.2,
#   'Max Temp': 283.58,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.61,
#   'Country': 'DE',
#   'Date': 1683818249},
#  {'City': 'barah',
#   'Lat': 13.7,
#   'Lng': 30.3667,
#   'Max Temp': 313.31,
#   'Humidity': 11,
#   'Cloudiness': 21,
#   'Wind Speed': 2.23,
#   'Country': 'SD',
#   'Date': 1683818249},
#  {'City': 'al jawf',
#   'Lat': 29.5,
#   'Lng': 38.75,
#   'Max Temp': 308.09,
#   'Humidity': 5,
#   'Cloudiness': 0,
#   'Wind Speed': 2.02,
#   'Country': 'SA',
#   'Date': 1683818190},
#  {'City': 'torit',
#   'Lat': 4.4133,
#   'Lng': 32.5678,
#   'Max Temp': 304.63,
#   'Humidity': 46,
#   'Cloudiness': 62,
#   'Wind Speed': 0.6,
#   'Country': 'SS',
#   'Date': 1683818249},
#  {'City': 'ballina',
#   'Lat': -28.8667,
#   'Lng': 153.5667,
#   'Max Temp': 287.6,
#   'Humidity': 99,
#   'Cloudiness': 20,
#   'Wind Speed': 0.92,
#   'Country': 'AU',
#   'Date': 1683818249},
#  {'City': 'santyoku',
#   'Lat': 37.4406,
#   'Lng': 129.1708,
#   'Max Temp': 286.96,
#   'Humidity': 77,
#   'Cloudiness': 9,
#   'Wind Speed': 4.21,
#   'Country': 'KR',
#   'Date': 1683818250},
#  {'City': 'campoverde',
#   'Lat': -8.4753,
#   'Lng': -74.8058,
#   'Max Temp': 301.98,
#   'Humidity': 59,
#   'Cloudiness': 91,
#   'Wind Speed': 0.73,
#   'Country': 'PE',
#   'Date': 1683818250},
#  {'City': "'ain merane",
#   'Lat': 36.1628,
#   'Lng': 0.9704,
#   'Max Temp': 300.81,
#   'Humidity': 32,
#   'Cloudiness': 1,
#   'Wind Speed': 5.55,
#   'Country': 'DZ',
#   'Date': 1683818250},
#  {'City': 'klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 284.66,
#   'Humidity': 84,
#   'Cloudiness': 16,
#   'Wind Speed': 2.67,
#   'Country': 'FO',
#   'Date': 1683818250},
#  {'City': 'guiuan',
#   'Lat': 11.0333,
#   'Lng': 125.7247,
#   'Max Temp': 301.41,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 4.8,
#   'Country': 'PH',
#   'Date': 1683818250},
#  {'City': 'usinsk',
#   'Lat': 65.9939,
#   'Lng': 57.5281,
#   'Max Temp': 273.9,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 4.35,
#   'Country': 'RU',
#   'Date': 1683818250},
#  {'City': 'zaozersk',
#   'Lat': 69.4005,
#   'Lng': 32.4476,
#   'Max Temp': 277.26,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'RU',
#   'Date': 1683818251},
#  {'City': 'paita',
#   'Lat': -5.0892,
#   'Lng': -81.1144,
#   'Max Temp': 298.42,
#   'Humidity': 73,
#   'Cloudiness': 24,
#   'Wind Speed': 4.93,
#   'Country': 'PE',
#   'Date': 1683818251},
#  {'City': 'motygino',
#   'Lat': 58.1831,
#   'Lng': 94.7592,
#   'Max Temp': 278.86,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 1.26,
#   'Country': 'RU',
#   'Date': 1683818251},
#  {'City': 'aur',
#   'Lat': 8.1499,
#   'Lng': 171.1687,
#   'Max Temp': 301.03,
#   'Humidity': 81,
#   'Cloudiness': 97,
#   'Wind Speed': 7.12,
#   'Country': 'MH',
#   'Date': 1683818251},
#  {'City': 'gamba',
#   'Lat': -2.65,
#   'Lng': 10,
#   'Max Temp': 301.82,
#   'Humidity': 74,
#   'Cloudiness': 72,
#   'Wind Speed': 4,
#   'Country': 'GA',
#   'Date': 1683818251},
#  {'City': 'holualoa',
#   'Lat': 19.6228,
#   'Lng': -155.9522,
#   'Max Temp': 295.06,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 2.68,
#   'Country': 'US',
#   'Date': 1683818252},
#  {'City': 'vallenar',
#   'Lat': -28.5708,
#   'Lng': -70.7581,
#   'Max Temp': 299.17,
#   'Humidity': 30,
#   'Cloudiness': 57,
#   'Wind Speed': 1.77,
#   'Country': 'CL',
#   'Date': 1683818252},
#  {'City': 'ormara',
#   'Lat': 25.2088,
#   'Lng': 64.6357,
#   'Max Temp': 302.09,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 7.07,
#   'Country': 'PK',
#   'Date': 1683818252},
#  {'City': 'shagonar',
#   'Lat': 51.5333,
#   'Lng': 92.8,
#   'Max Temp': 282.68,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 0.71,
#   'Country': 'RU',
#   'Date': 1683818252},
#  {'City': 'kununurra',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 293.14,
#   'Humidity': 34,
#   'Cloudiness': 6,
#   'Wind Speed': 3.6,
#   'Country': 'AU',
#   'Date': 1683818207},
#  {'City': 'puerto rico',
#   'Lat': -26.796,
#   'Lng': -55.024,
#   'Max Temp': 292.47,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 1.45,
#   'Country': 'AR',
#   'Date': 1683818252},
#  {'City': 'lazaro cardenas',
#   'Lat': 17.9583,
#   'Lng': -102.2,
#   'Max Temp': 301.92,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 1.52,
#   'Country': 'MX',
#   'Date': 1683818253},
#  {'City': 'madalena',
#   'Lat': 41.2162,
#   'Lng': -8.3345,
#   'Max Temp': 296.35,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 4.85,
#   'Country': 'PT',
#   'Date': 1683818253},
#  {'City': 'alta',
#   'Lat': 69.9689,
#   'Lng': 23.2717,
#   'Max Temp': 282.74,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 1.03,
#   'Country': 'NO',
#   'Date': 1683818253},
#  {'City': 'san julian',
#   'Lat': 21.0167,
#   'Lng': -102.1667,
#   'Max Temp': 294.66,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 4.29,
#   'Country': 'MX',
#   'Date': 1683818253},
#  {'City': 'znamenskoye',
#   'Lat': 57.1281,
#   'Lng': 73.8282,
#   'Max Temp': 280.46,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Country': 'RU',
#   'Date': 1683818253},
#  {'City': 'bangassou',
#   'Lat': 4.7413,
#   'Lng': 22.8184,
#   'Max Temp': 305.9,
#   'Humidity': 37,
#   'Cloudiness': 59,
#   'Wind Speed': 3.22,
#   'Country': 'CF',
#   'Date': 1683818253}]

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          576
# Lat           576
# Lng           576
# Max Temp      576
# Humidity      576
# Cloudiness    576
# Wind Speed    576
# Country       576
# Date          576
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             basotu  -4.3667   35.0833    294.15        60          55
# 1         himatnagar  23.6000   72.9500    308.78        13           0
# 2      blackmans bay -43.0167  147.3167    282.22        86          99
# 3          grytviken -54.2811  -36.5092    271.36        76          41
# 4  port-aux-francais -49.3500   70.2167    280.56        93         100
#
#    Wind Speed Country        Date
# 0        2.96      TZ  1683818132
# 1        5.14      IN  1683818132
# 2        2.73      AU  1683818132
# 3        4.60      GS  1683818132
# 4       17.36      TF  1683818132

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                   basotu  -4.3667   35.0833    294.15        60          55
# 1               himatnagar  23.6000   72.9500    308.78        13           0
# 2            blackmans bay -43.0167  147.3167    282.22        86          99
# 3                grytviken -54.2811  -36.5092    271.36        76          41
# 4        port-aux-francais -49.3500   70.2167    280.56        93         100
# ...                    ...      ...       ...       ...       ...         ...
# 571               madalena  41.2162   -8.3345    296.35        41           0
# 572                   alta  69.9689   23.2717    282.74        79          75
# 573             san julian  21.0167 -102.1667    294.66        21           0
# 574            znamenskoye  57.1281   73.8282    280.46        67         100
# 575              bangassou   4.7413   22.8184    305.90        37          59
#
#          Wind Speed Country        Date
# City_ID
# 0              2.96      TZ  1683818132
# 1              5.14      IN  1683818132
# 2              2.73      AU  1683818132
# 3              4.60      GS  1683818132
# 4             17.36      TF  1683818132
# ...             ...     ...         ...
# 571            4.85      PT  1683818253
# 572            1.03      NO  1683818253
# 573            4.29      MX  1683818253
# 574            4.63      RU  1683818253
# 575            3.22      CF  1683818253
#
# [576 rows x 9 columns]

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'])

# Incorporate the other graph properties
plt.title("City Max Temperature by Latitude")
plt.xlabel("Latitude")
plt.ylabel("Temperature (K)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'])

# Incorporate the other graph properties
plt.title("City Humidity by Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'])

# Incorporate the other graph properties
plt.title("City Cloudiness by Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'])


# Incorporate the other graph properties
plt.title("City Wind Speed by Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plots(x,y,annocoords):
    r=st.pearsonr(x,y)
    print(f"r value = {r}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    equation = f"y = {slope}*x + {intercept}"
    regression = x * slope + intercept
    plt.plot(x, regression, "r-")
    plt.annotate(equation, annocoords)
    plt.scatter(x,y)

# %%
city_data_df
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                   basotu  -4.3667   35.0833    294.15        60          55
# 1               himatnagar  23.6000   72.9500    308.78        13           0
# 2            blackmans bay -43.0167  147.3167    282.22        86          99
# 3                grytviken -54.2811  -36.5092    271.36        76          41
# 4        port-aux-francais -49.3500   70.2167    280.56        93         100
# ...                    ...      ...       ...       ...       ...         ...
# 571               madalena  41.2162   -8.3345    296.35        41           0
# 572                   alta  69.9689   23.2717    282.74        79          75
# 573             san julian  21.0167 -102.1667    294.66        21           0
# 574            znamenskoye  57.1281   73.8282    280.46        67         100
# 575              bangassou   4.7413   22.8184    305.90        37          59
#
#          Wind Speed Country        Date
# City_ID
# 0              2.96      TZ  1683818132
# 1              5.14      IN  1683818132
# 2              2.73      AU  1683818132
# 3              4.60      GS  1683818132
# 4             17.36      TF  1683818132
# ...             ...     ...         ...
# 571            4.85      PT  1683818253
# 572            1.03      NO  1683818253
# 573            4.29      MX  1683818253
# 574            4.63      RU  1683818253
# 575            3.22      CF  1683818253
#
# [576 rows x 9 columns]

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1         himatnagar  23.6000   72.9500    308.78        13           0
# 5        yellowknife  62.4560 -114.3525    283.46        53           2
# 6               amga  60.8953  131.9608    273.77        97         100
# 7             lompoc  34.6391 -120.4579    286.40        83          70
# 8          kavaratti  10.5669   72.6420    302.83        71          55
#
#          Wind Speed Country        Date
# City_ID
# 1              5.14      IN  1683818132
# 5              4.47      CA  1683818132
# 6              3.33      RU  1683818133
# 7              1.34      US  1683818133
# 8              2.50      IN  1683818133

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                             basotu  -4.3667   35.0833    294.15        60
# 2                      blackmans bay -43.0167  147.3167    282.22        86
# 3                          grytviken -54.2811  -36.5092    271.36        76
# 4                  port-aux-francais -49.3500   70.2167    280.56        93
# 9        edinburgh of the seven seas -37.0676  -12.3116    289.39        75
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                55        2.96      TZ  1683818132
# 2                99        2.73      AU  1683818132
# 3                41        4.60      GS  1683818132
# 4               100       17.36      TF  1683818132
# 9                94       10.84      SH  1683818133

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plots(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], (10,280))
plt.xlabel("Latitude")
plt.ylabel("Temperature")
# Out:
# r value = PearsonRResult(statistic=-0.8007755806419028, pvalue=6.159414699827733e-86)
# Text(0, 0.5, 'Temperature')

# %%
# Linear regression on Southern Hemisphere
plots(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], (-50,280))
plt.xlabel("Latitude")
plt.ylabel("Temperature")
# Out:
# r value = PearsonRResult(statistic=0.8353034089384254, pvalue=1.4853840070304404e-52)
# Text(0, 0.5, 'Temperature')

# %% [markdown]
# **Discussion about the linear relationship:** These linear relationships show that as the latitude decreases for the northern hemisphere the temperature increases and that as latitude increases for the southern hemisphere so do temperatures. This shows that the closer you get to the equater the higher the temperatures get. Both r values were were around 0.8 which indicates a strong linear correlation between temperature and latitude for both hemispheres.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plots(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], (10,40))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
# Out:
# r value = PearsonRResult(statistic=0.14620978012179364, pvalue=0.004339839717170898)
# Text(0, 0.5, 'Humidity')

# %%
# Southern Hemisphere
plots(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], (-50,40))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
# Out:
# r value = PearsonRResult(statistic=0.01651528737924466, pvalue=0.8178247276092471)
# Text(0, 0.5, 'Humidity')

# %% [markdown]
# **Discussion about the linear relationship:** There does not appear to be any correlation between the latitude and the humidity for either hemisphere. The r values are very close to zero for both hemispheres.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plots(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], (10,40))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
# Out:
# r value = PearsonRResult(statistic=0.0025262961486034116, pvalue=0.9609038676116586)
# Text(0, 0.5, 'Cloudiness')

# %%
# Southern Hemisphere
plots(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], (-50,40))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
# Out:
# r value = PearsonRResult(statistic=0.06403261612740012, pvalue=0.3713545231557323)
# Text(0, 0.5, 'Cloudiness')

# %% [markdown]
# **Discussion about the linear relationship:** Same thing as for humidity. The r value for both hemispheres is close to 0 indicating that there is no linear relationship between cloudiness and latitude for either hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plots(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], (10,10))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
# Out:
# r value = PearsonRResult(statistic=-0.03973818307598286, pvalue=0.4404881299679353)
# Text(0, 0.5, 'Wind Speed')

# %%
# Southern Hemisphere
plots(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], (-50,10))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
# Out:
# r value = PearsonRResult(statistic=-0.08745577367426213, pvalue=0.22169566383941722)
# Text(0, 0.5, 'Wind Speed')

# %% [markdown]
# **Discussion about the linear relationship:** the r values for both hemispheres are very close to 0 indicating that there is no correlation between these two variables for either hemisphere. The linear relationship is weak.
