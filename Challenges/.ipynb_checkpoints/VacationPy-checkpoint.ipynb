# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0             albany  42.6001  -73.9662      7.97        41
# 1        1              xinji  37.9028  115.2036     24.53        39
# 2        2   playa del ingles  27.7567  -15.5787     19.86        73
# 3        3           waitangi -43.9535 -176.5597     15.46        92
# 4        4  port-aux-francais -49.3500   70.2167      8.07        98
#
#    Cloudiness  Wind Speed Country        Date
# 0           1        1.79      US  1684373401
# 1           0        3.19      CN  1684373841
# 2           1        4.96      ES  1684373673
# 3         100        1.79      NZ  1684373544
# 4         100       14.38      TF  1684373842

# %%
city_data_df
# Out:
#      City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0          0             albany  42.6001  -73.9662      7.97        41
# 1          1              xinji  37.9028  115.2036     24.53        39
# 2          2   playa del ingles  27.7567  -15.5787     19.86        73
# 3          3           waitangi -43.9535 -176.5597     15.46        92
# 4          4  port-aux-francais -49.3500   70.2167      8.07        98
# ..       ...                ...      ...       ...       ...       ...
# 583      583           griffith  41.5284  -87.4237     11.81        76
# 584      584             vernon  50.2581 -119.2691     28.75        32
# 585      585       bogorodskoye  56.5500   37.8833     11.40        86
# 586      586            bubaque  11.2833  -15.8333     26.82        73
# 587      587       shkurinskaya  46.5858   39.3599     10.71        86
#
#      Cloudiness  Wind Speed Country        Date
# 0             1        1.79      US  1684373401
# 1             0        3.19      CN  1684373841
# 2             1        4.96      ES  1684373673
# 3           100        1.79      NZ  1684373544
# 4           100       14.38      TF  1684373842
# ..          ...         ...     ...         ...
# 583           0        4.12      US  1684373946
# 584          27        0.51      CA  1684373947
# 585          99        2.81      RU  1684373947
# 586          99        4.78      GW  1684373947
# 587           0        3.81      RU  1684373947
#
# [588 rows x 10 columns]

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
cities = city_data_df.hvplot.points('Lat', 'Lng', color = 'City', size = 'Humidity')

# Display the map
cities
# Out:
# :Points   [Lat,Lng]   (City,Humidity)

# %%
city_data_df['Max Temp'].describe()
# Out:
# count    588.000000
# mean      19.053078
# std        8.795086
# min       -7.050000
# 25%       12.645000
# 50%       20.590000
# 75%       26.592500
# max       36.820000
# Name: Max Temp, dtype: float64

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_df = city_data_df.loc[(city_data_df['Max Temp']<27)
                           & (city_data_df['Max Temp']>21)
                           & (city_data_df['Wind Speed']<4.5)
                           & (city_data_df['Cloudiness']==0)]

# Drop any rows with null values
ideal_df = ideal_df.dropna()

# Display sample data
ideal_df
# Out:
#      City_ID           City      Lat       Lng  Max Temp  Humidity  \
# 1          1          xinji  37.9028  115.2036     24.53        39
# 9          9      adamstown -25.0660 -130.1015     23.44        77
# 40        40        lincoln  40.8000  -96.6670     24.95        39
# 61        61     whitehorse  60.7161 -135.0538     26.43        13
# 76        76       marshall  34.3834  -86.3333     22.03        94
# 80        80      ascension  30.2169  -90.9001     25.03        86
# 105      105         ma'rib  15.4591   45.3253     26.17        45
# 112      112      sandpoint  48.2766 -116.5533     25.02        63
# 138      138           tura  25.5198   90.2201     25.53        66
# 202      202      el colomo  19.0500 -104.2500     26.26        71
# 226      226       elk city  35.4120  -99.4043     23.12        64
# 230      230      brookings  44.3114  -96.7984     21.70        36
# 240      240     fort bragg  35.1390  -79.0060     22.91        59
# 253      253         sokcho  38.2083  128.5911     23.34        60
# 280      280      carnarvon -24.8667  113.6333     23.81        43
# 307      307       fangshan  39.6983  115.9925     24.52        27
# 316      316     saint-paul -21.0096   55.2707     24.44        89
# 322      322  nebraska city  40.6767  -95.8592     22.91        43
# 404      404         lawton  34.6087  -98.3903     24.13        69
# 419      419      ketchikan  55.3422 -131.6461     25.26        33
# 452      452          korla  41.7597   86.1469     23.99        29
# 505      505           hami  42.8000   93.4500     24.55        18
# 521      521         chaman  30.9236   66.4512     22.12        17
# 551      551        al jawf  29.5000   38.7500     23.20        26
# 569      569          ha'il  27.5219   41.6907     25.01        33
# 571      571      robertson  36.5167  -86.8667     22.83        75
#
#      Cloudiness  Wind Speed Country        Date
# 1             0        3.19      CN  1684373841
# 9             0        2.40      PN  1684373843
# 40            0        4.12      US  1684373388
# 61            0        3.09      CA  1684373614
# 76            0        0.45      US  1684373855
# 80            0        0.00      US  1684373855
# 105           0        2.36      YE  1684373859
# 112           0        0.00      US  1684373860
# 138           0        2.28      IN  1684373442
# 202           0        2.53      MX  1684373875
# 226           0        3.60      US  1684373878
# 230           0        4.12      US  1684373858
# 240           0        1.54      US  1684373871
# 253           0        1.03      KR  1684373883
# 280           0        1.89      AU  1684373888
# 307           0        2.67      CN  1684373893
# 316           0        2.05      RE  1684373895
# 322           0        1.54      US  1684373896
# 404           0        4.02      US  1684373912
# 419           0        3.09      US  1684373914
# 452           0        4.36      CN  1684373924
# 505           0        2.14      CN  1684373932
# 521           0        2.80      PK  1684373935
# 551           0        3.73      SA  1684373940
# 569           0        2.06      SA  1684373943
# 571           0        0.00      US  1684373944

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
#               City Country      Lat       Lng  Humidity Hotel Name
# 1            xinji      CN  37.9028  115.2036        39
# 9        adamstown      PN -25.0660 -130.1015        77
# 40         lincoln      US  40.8000  -96.6670        39
# 61      whitehorse      CA  60.7161 -135.0538        13
# 76        marshall      US  34.3834  -86.3333        94
# 80       ascension      US  30.2169  -90.9001        86
# 105         ma'rib      YE  15.4591   45.3253        45
# 112      sandpoint      US  48.2766 -116.5533        63
# 138           tura      IN  25.5198   90.2201        66
# 202      el colomo      MX  19.0500 -104.2500        71
# 226       elk city      US  35.4120  -99.4043        64
# 230      brookings      US  44.3114  -96.7984        36
# 240     fort bragg      US  35.1390  -79.0060        59
# 253         sokcho      KR  38.2083  128.5911        60
# 280      carnarvon      AU -24.8667  113.6333        43
# 307       fangshan      CN  39.6983  115.9925        27
# 316     saint-paul      RE -21.0096   55.2707        89
# 322  nebraska city      US  40.6767  -95.8592        43
# 404         lawton      US  34.6087  -98.3903        69
# 419      ketchikan      US  55.3422 -131.6461        33
# 452          korla      CN  41.7597   86.1469        29
# 505           hami      CN  42.8000   93.4500        18
# 521         chaman      PK  30.9236   66.4512        17
# 551        al jawf      SA  29.5000   38.7500        26
# 569          ha'il      SA  27.5219   41.6907        33
# 571      robertson      US  36.5167  -86.8667        75

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    'categories': 'accomodation.hotel',
    'apiKey': geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lon = row['Lng']
    lat = row['Lat']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params = params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# xinji - nearest hotel: No hotel found
# adamstown - nearest hotel: No hotel found
# lincoln - nearest hotel: No hotel found
# whitehorse - nearest hotel: No hotel found
# marshall - nearest hotel: No hotel found
# ascension - nearest hotel: No hotel found
# ma'rib - nearest hotel: No hotel found
# sandpoint - nearest hotel: No hotel found
# tura - nearest hotel: No hotel found
# el colomo - nearest hotel: No hotel found
# elk city - nearest hotel: No hotel found
# brookings - nearest hotel: No hotel found
# fort bragg - nearest hotel: No hotel found
# sokcho - nearest hotel: No hotel found
# carnarvon - nearest hotel: No hotel found
# fangshan - nearest hotel: No hotel found
# saint-paul - nearest hotel: No hotel found
# nebraska city - nearest hotel: No hotel found
# lawton - nearest hotel: No hotel found
# ketchikan - nearest hotel: No hotel found
# korla - nearest hotel: No hotel found
# hami - nearest hotel: No hotel found
# chaman - nearest hotel: No hotel found
# al jawf - nearest hotel: No hotel found
# ha'il - nearest hotel: No hotel found
# robertson - nearest hotel: No hotel found
#               City Country      Lat       Lng  Humidity      Hotel Name
# 1            xinji      CN  37.9028  115.2036        39  No hotel found
# 9        adamstown      PN -25.0660 -130.1015        77  No hotel found
# 40         lincoln      US  40.8000  -96.6670        39  No hotel found
# 61      whitehorse      CA  60.7161 -135.0538        13  No hotel found
# 76        marshall      US  34.3834  -86.3333        94  No hotel found
# 80       ascension      US  30.2169  -90.9001        86  No hotel found
# 105         ma'rib      YE  15.4591   45.3253        45  No hotel found
# 112      sandpoint      US  48.2766 -116.5533        63  No hotel found
# 138           tura      IN  25.5198   90.2201        66  No hotel found
# 202      el colomo      MX  19.0500 -104.2500        71  No hotel found
# 226       elk city      US  35.4120  -99.4043        64  No hotel found
# 230      brookings      US  44.3114  -96.7984        36  No hotel found
# 240     fort bragg      US  35.1390  -79.0060        59  No hotel found
# 253         sokcho      KR  38.2083  128.5911        60  No hotel found
# 280      carnarvon      AU -24.8667  113.6333        43  No hotel found
# 307       fangshan      CN  39.6983  115.9925        27  No hotel found
# 316     saint-paul      RE -21.0096   55.2707        89  No hotel found
# 322  nebraska city      US  40.6767  -95.8592        43  No hotel found
# 404         lawton      US  34.6087  -98.3903        69  No hotel found
# 419      ketchikan      US  55.3422 -131.6461        33  No hotel found
# 452          korla      CN  41.7597   86.1469        29  No hotel found
# 505           hami      CN  42.8000   93.4500        18  No hotel found
# 521         chaman      PK  30.9236   66.4512        17  No hotel found
# 551        al jawf      SA  29.5000   38.7500        26  No hotel found
# 569          ha'il      SA  27.5219   41.6907        33  No hotel found
# 571      robertson      US  36.5167  -86.8667        75  No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotelmap = hotel_df.hvplot.points("Lng","Lat", geo = True, color = "City", size = "Humidity", hover_cols = ['Hotel Name', 'Country'])
                            

# Display the map
hotelmap
# Out:
# :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
